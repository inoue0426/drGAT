# 41 2025-03-20 12:58:09.142499 0 days 00:01:13.029877           NaN
# 43 2025-03-20 12:57:02.269685 0 days 00:00:02.536864           NaN
# 44 2025-03-20 12:58:18.665440 0 days 00:01:16.365866           NaN
# 45 2025-03-20 12:59:08.462102 0 days 00:00:59.292305           NaN
# 46 2025-03-20 12:59:21.229446 0 days 00:01:02.534258           NaN
# 47 2025-03-20 13:00:07.714563 0 days 00:00:59.225074           NaN
# 48 2025-03-20 13:02:43.831594 0 days 00:03:22.572751           NaN
# 50 2025-03-20 13:01:51.886003 0 days 00:01:43.647644           NaN
# 51 2025-03-20 13:03:35.403984 0 days 00:01:43.488081           NaN
# 52 2025-03-20 13:04:34.060569 0 days 00:01:50.199812           NaN
# 53 2025-03-20 13:05:19.074266 0 days 00:01:43.643246           NaN
# 54 2025-03-20 13:06:24.533373 0 days 00:01:50.443154           NaN
# 55 2025-03-20 13:07:02.975384 0 days 00:01:43.874226           NaN
# 56 2025-03-20 13:08:15.433625 0 days 00:01:50.869472           NaN
# 57 2025-03-20 13:08:46.559494 0 days 00:01:43.558027           NaN
# 58 2025-03-20 13:10:06.577949 0 days 00:01:51.110815           NaN
# 59 2025-03-20 13:10:31.890606 0 days 00:01:45.303717           NaN
# 60 2025-03-20 13:11:57.579211 0 days 00:01:50.969428           NaN
# 61 2025-03-20 13:13:04.577973 0 days 00:02:32.659602           NaN
# 62 2025-03-20 13:14:38.758383 0 days 00:02:41.148943           NaN
# 64 2025-03-20 13:15:37.619403 0 days 00:02:32.608616           NaN
# 65 2025-03-20 13:16:08.208504 0 days 00:02:37.291531           NaN
# 66 2025-03-20 13:16:08.313845 0 days 00:02:37.396553           NaN
# 67 2025-03-20 13:16:16.639080 0 days 00:02:45.710654           NaN
# 68 2025-03-20 13:16:10.463673 0 days 00:02:39.530955           NaN
#
#    params_activation  ... params_nesterov  params_optimizer  \
# 6              swish  ...             NaN             AdamW
# 7               relu  ...             NaN              Adam
# 18             swish  ...             NaN             AdamW
# 19              gelu  ...             NaN              Adam
# 21             swish  ...             NaN             AdamW
# 22             swish  ...             NaN             AdamW
# 23             swish  ...             NaN             AdamW
# 24             swish  ...             NaN             AdamW
# 25             swish  ...             NaN             AdamW
# 26             swish  ...             NaN             AdamW
# 27              gelu  ...             NaN             AdamW
# 28              gelu  ...             NaN             AdamW
# 29             swish  ...             NaN              Adam
# 30              gelu  ...             NaN             AdamW
# 31             swish  ...             NaN             AdamW
# 32             swish  ...             NaN             AdamW
# 33             swish  ...             NaN             AdamW
# 34             swish  ...             NaN              Adam
# 36             swish  ...             NaN             AdamW
# 37             swish  ...             NaN              Adam
# 39             swish  ...            True               SGD
# 40             swish  ...            True               SGD
# 41             swish  ...            True               SGD
# 43             swish  ...            True               SGD
# 44             swish  ...            True               SGD
# 45             swish  ...            True               SGD
# 46             swish  ...            True               SGD
# 47             swish  ...            True               SGD
# 48             swish  ...            True               SGD
# 50              gelu  ...            True               SGD
# 51              gelu  ...           False               SGD
# 52              gelu  ...           False               SGD
# 53              gelu  ...           False               SGD
# 54              gelu  ...           False               SGD
# 55              gelu  ...           False               SGD
# 56              gelu  ...           False               SGD
# 57              gelu  ...           False               SGD
# 58              gelu  ...             NaN              Adam
# 59              gelu  ...             NaN              Adam
# 60              gelu  ...           False               SGD
# 61              gelu  ...           False               SGD
# 62              gelu  ...           False               SGD
# 64              gelu  ...           False               SGD
# 65              gelu  ...           False               SGD
# 66              gelu  ...           False               SGD
# 67              gelu  ...           False               SGD
# 68              gelu  ...           False               SGD
#
#     params_patience_plateau  params_scheduler  params_step_size  \
# 6                       NaN            Cosine               NaN
# 7                       NaN              Step              17.0
# 18                      9.0           Plateau               NaN
# 19                      NaN            Cosine               NaN
# 21                     10.0           Plateau               NaN
# 22                     10.0           Plateau               NaN
# 23                     10.0           Plateau               NaN
# 24                      3.0           Plateau               NaN
# 25                      NaN              Step              30.0
# 26                      NaN              Step              30.0
# 27                      NaN              Step              30.0
# 28                      NaN              Step              30.0
# 29                      NaN              Step              10.0
# 30                      NaN              Step              22.0
# 31                      NaN              Step              23.0
# 32                      NaN              Step              22.0
# 33                      NaN              Step              17.0
# 34                      NaN              Step              25.0
# 36                      NaN            Cosine               NaN
# 37                      NaN            Cosine               NaN
# 39                      NaN              Step              26.0
# 40                      NaN              Step              25.0
# 41                      NaN              Step              26.0
# 43                      NaN              Step              26.0
# 44                      NaN              Step              26.0
# 45                      NaN              Step              26.0
# 46                      NaN              Step              26.0
# 47                      NaN              Step              27.0
# 48                      NaN              None               NaN
# 50                      NaN              None               NaN
# 51                      NaN              None               NaN
# 52                      NaN              None               NaN
# 53                      NaN              None               NaN
# 54                      NaN              None               NaN
# 55                      NaN              None               NaN
# 56                      NaN              None               NaN
# 57                      NaN              None               NaN
# 58                      NaN              None               NaN
# 59                      NaN              None               NaN
# 60                      NaN              None               NaN
# 61                      NaN              None               NaN
# 62                      NaN              None               NaN
# 64                      NaN              None               NaN
# 65                      NaN              None               NaN
# 66                      NaN              None               NaN
# 67                      NaN              None               NaN
# 68                      NaN              None               NaN
#
#     params_thresh_plateau params_weight_decay  \
# 6                     NaN            0.000356
# 7                     NaN            0.000001
# 18               0.001240            0.000025
# 19                    NaN            0.000010
# 21               0.000198            0.007158
# 22               0.000137            0.002076
# 23               0.000107            0.007106
# 24               0.000109            0.008774
# 25                    NaN            0.002027
# 26                    NaN            0.001298
# 27                    NaN            0.000445
# 28                    NaN            0.000549
# 29                    NaN            0.002685
# 30                    NaN            0.000053
# 31                    NaN            0.000519
# 32                    NaN            0.000607
# 33                    NaN            0.000050
# 34                    NaN            0.000002
# 36                    NaN            0.000651
# 37                    NaN            0.003249
# 39                    NaN            0.001037
# 40                    NaN            0.000915
# 41                    NaN            0.000994
# 43                    NaN            0.000003
# 44                    NaN            0.001147
# 45                    NaN            0.004479
# 46                    NaN            0.000992
# 47                    NaN            0.003980
# 48                    NaN            0.004233
# 50                    NaN            0.000260
# 51                    NaN            0.000077
# 52                    NaN            0.000052
# 53                    NaN            0.000074
# 54                    NaN            0.000076
# 55                    NaN            0.000057
# 56                    NaN            0.000070
# 57                    NaN            0.000072
# 58                    NaN            0.000021
# 59                    NaN            0.000021
# 60                    NaN            0.000107
# 61                    NaN            0.000105
# 62                    NaN            0.000124
# 64                    NaN            0.000149
# 65                    NaN            0.000035
# 66                    NaN            0.000145
# 67                    NaN            0.000039
# 68                    NaN            0.000033
#
#     user_attrs_early_stopping_epoch  user_attrs_status     state
# 6                               NaN                NaN  COMPLETE
# 7                               NaN           CUDA OOM  COMPLETE
# 18                              NaN                NaN  COMPLETE
# 19                              NaN           CUDA OOM  COMPLETE
# 21                              NaN                NaN  COMPLETE
# 22                              NaN                NaN  COMPLETE
# 23                              NaN                NaN  COMPLETE
# 24                              NaN                NaN  COMPLETE
# 25                              NaN                NaN  COMPLETE
# 26                              NaN                NaN  COMPLETE
# 27                              NaN                NaN  COMPLETE
# 28                              NaN                NaN  COMPLETE
# 29                              NaN                NaN  COMPLETE
# 30                              NaN                NaN  COMPLETE
# 31                              NaN                NaN  COMPLETE
# 32                              NaN                NaN  COMPLETE
# 33                              NaN                NaN  COMPLETE
# 34                              NaN                NaN  COMPLETE
# 36                              NaN                NaN  COMPLETE
# 37                              NaN           CUDA OOM  COMPLETE
# 39                              NaN                NaN  COMPLETE
# 40                              NaN                NaN  COMPLETE
# 41                              NaN                NaN  COMPLETE
# 43                              NaN           CUDA OOM  COMPLETE
# 44                              NaN                NaN  COMPLETE
# 45                              NaN                NaN  COMPLETE
# 46                              NaN                NaN  COMPLETE
# 47                              NaN                NaN  COMPLETE
# 48                              NaN                NaN  COMPLETE
# 50                              NaN                NaN  COMPLETE
# 51                              NaN                NaN  COMPLETE
# 52                              NaN                NaN  COMPLETE
# 53                              NaN                NaN  COMPLETE
# 54                              NaN                NaN  COMPLETE
# 55                              NaN                NaN  COMPLETE
# 56                              NaN                NaN  COMPLETE
# 57                              NaN                NaN  COMPLETE
# 58                              NaN                NaN  COMPLETE
# 59                              NaN                NaN  COMPLETE
# 60                              NaN                NaN  COMPLETE
# 61                              NaN                NaN  COMPLETE
# 62                              NaN                NaN  COMPLETE
# 64                              NaN                NaN  COMPLETE
# 65                              NaN                NaN  COMPLETE
# 66                              NaN                NaN  COMPLETE
# 67                              NaN                NaN  COMPLETE
# 68                              NaN                NaN  COMPLETE
#
# [47 rows x 33 columns]

# %%
# test_drug = test_data.values[:, 0]
# test_cell = test_data.values[:, 1]

# test_labels = np.load("data/test_labels.npy")
# test_labels = torch.tensor(test_labels).float()
# test = [drug, cell, gene, edge_index, test_drug, test_cell, test_labels]

# %%
# prob, res, test_attention = drGAT.eval(model, test)

# %%
# Out:
# ['maximizemaximizemaximizemaximize']
