# %%
import os
import sys

import optuna
import pandas as pd

current_dir = os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, ".."))
sys.path.append(parent_dir)

from metrics import get_parsed_df

# %%
task = "cell"
method = "GATv2"
study = optuna.create_study(
    storage=f"sqlite:///{method}_{task}_small.sqlite3",
    study_name=method,
    load_if_exists=True,
)
tmp = study.trials_dataframe().dropna(
    subset=["values_0", "values_1", "values_2", "values_3"]
)
tmp = tmp[[i for i in tmp.columns if "params" in i]]
df = (
    study.trials_dataframe()
    .dropna(subset=["values_0", "values_1", "values_2", "values_3"])
    .iloc[:, 20:-2]
)
df.columns = [i.replace("user_attrs_", "") for i in df.columns]

print(df.shape)
n = df.shape[0]
if n > 0:
    parsed_df = get_parsed_df(df)
    parsed_df = pd.concat([parsed_df, tmp], axis=1)
    parsed_df.sort_values("AUPR", ascending=False).head()

parsed_df if n > 0 else None
# Out:
# [I 2025-04-15 13:36:41,158] Using an existing study with name 'GATv2' instead of creating a new one.
# (67, 22)
#                    ACC               AUPR              AUROC  \
# 3    0.4929 (± 0.0745)  0.5449 (± 0.0712)  0.4986 (± 0.0283)
# 17   0.4604 (± 0.0674)  0.5515 (± 0.0754)  0.5048 (± 0.0283)
# 20   0.4711 (± 0.0729)  0.5466 (± 0.0712)  0.5013 (± 0.0248)
# 23   0.4569 (± 0.0673)   0.547 (± 0.0763)  0.5021 (± 0.0287)
# 36    0.4628 (± 0.068)  0.5476 (± 0.0711)  0.5029 (± 0.0298)
# ..                 ...                ...                ...
# 684  0.4564 (± 0.0672)  0.5491 (± 0.0702)  0.5052 (± 0.0266)
# 694  0.4615 (± 0.0703)  0.5562 (± 0.0741)  0.5109 (± 0.0313)
# 699  0.4567 (± 0.0674)  0.5475 (± 0.0693)  0.5035 (± 0.0248)
# 706  0.4619 (± 0.0672)   0.546 (± 0.0758)  0.4991 (± 0.0293)
# 708  0.4567 (± 0.0677)  0.5444 (± 0.0697)   0.499 (± 0.0278)
#
#           Balanced_ACC                 F1             Recall  \
# 3    0.5014 (± 0.0125)   0.362 (± 0.3089)  0.4558 (± 0.4392)
# 17   0.5013 (± 0.0066)  0.0404 (± 0.1531)    0.05 (± 0.1996)
# 20   0.4995 (± 0.0029)  0.0668 (± 0.2073)  0.0867 (± 0.2765)
# 23   0.4997 (± 0.0023)  0.0163 (± 0.0892)  0.0187 (± 0.1214)
# 36   0.5012 (± 0.0103)  0.0371 (± 0.1173)   0.029 (± 0.1091)
# ..                 ...                ...                ...
# 684  0.4995 (± 0.0023)  0.0046 (± 0.0177)  0.0025 (± 0.0096)
# 694  0.5023 (± 0.0077)  0.0837 (± 0.2055)  0.1039 (± 0.2786)
# 699  0.4998 (± 0.0009)  0.0019 (± 0.0125)   0.001 (± 0.0069)
# 706  0.5003 (± 0.0048)  0.0244 (± 0.1118)  0.0223 (± 0.1089)
# 708  0.4999 (± 0.0014)  0.0008 (± 0.0062)  0.0004 (± 0.0032)
#
#              Precision  params_T_max params_activation  params_dropout1  \
# 3    0.4178 (± 0.2598)           NaN              gelu             0.40
# 17    0.073 (± 0.2145)          44.0              relu             0.20
# 20   0.0919 (± 0.2465)          48.0              gelu             0.25
# 23   0.0615 (± 0.1991)          40.0              relu             0.10
# 36   0.1512 (± 0.2442)          40.0              relu             0.15
# ..                 ...           ...               ...              ...
# 684  0.0539 (± 0.1783)          32.0              relu             0.20
# 694  0.1928 (± 0.3174)           NaN              gelu             0.35
# 699   0.0142 (± 0.079)          49.0              gelu             0.10
# 706   0.059 (± 0.1856)           NaN              gelu             0.45
# 708  0.0111 (± 0.0861)           NaN              gelu             0.15
#
#      params_dropout2  params_heads  params_hidden1  params_hidden2  \
# 3               0.15             2             686              84
# 17              0.40             2             450             163
# 20              0.40             2             335             153
# 23              0.30             4             482              84
# 36              0.40             3             943              67
# ..               ...           ...             ...             ...
# 684             0.20             2             343              69
# 694             0.25             3             391             142
# 699             0.15             3             481             103
# 706             0.50             2             561             157
# 708             0.15             2             686              65
#
#      params_hidden3  params_lr params_optimizer params_scheduler  \
# 3                84   0.003797             Adam             None
# 17               46   0.002605            AdamW           Cosine
# 20               92   0.007337             Adam           Cosine
# 23               76   0.000305            AdamW           Cosine
# 36               32   0.000040            AdamW           Cosine
# ..              ...        ...              ...              ...
# 684              68   0.000470            AdamW           Cosine
# 694              93   0.002605             Adam             None
# 699              53   0.000186             Adam           Cosine
# 706             136   0.001432             Adam             None
# 708              40   0.003797             Adam             None
#
#      params_weight_decay
# 3               0.000923
# 17              0.000024
# 20              0.000001
# 23              0.000022
# 36              0.000043
# ..                   ...
# 684             0.000005
# 694             0.000024
# 699             0.006829
# 706             0.000109
# 708             0.000923
#
# [67 rows x 19 columns]

# %%
parsed_df.sort_values("ACC", ascending=False).head(3)
# Out:
#                    ACC               AUPR              AUROC  \
# 3    0.4929 (± 0.0745)  0.5449 (± 0.0712)  0.4986 (± 0.0283)
# 493  0.4795 (± 0.0739)  0.5498 (± 0.0757)  0.5028 (± 0.0301)
# 463  0.4725 (± 0.0671)    0.5608 (± 0.07)   0.514 (± 0.0295)
#
#           Balanced_ACC                 F1             Recall  \
# 3    0.5014 (± 0.0125)   0.362 (± 0.3089)  0.4558 (± 0.4392)
# 493  0.5001 (± 0.0078)  0.1935 (± 0.3034)  0.2571 (± 0.4181)
# 463   0.5039 (± 0.009)  0.1232 (± 0.2301)  0.1412 (± 0.3126)
#
#              Precision  params_T_max params_activation  params_dropout1  \
# 3    0.4178 (± 0.2598)           NaN              gelu             0.40
# 493    0.216 (± 0.298)           NaN              gelu             0.40
# 463  0.3049 (± 0.3587)           NaN              relu             0.15
#
#      params_dropout2  params_heads  params_hidden1  params_hidden2  \
# 3               0.15             2             686              84
# 493             0.30             3             910             171
# 463             0.25             3             315             152
#
#      params_hidden3  params_lr params_optimizer params_scheduler  \
# 3                84   0.003797             Adam             None
# 493              99   0.000134            AdamW             None
# 463             141   0.000994             Adam             None
#
#      params_weight_decay
# 3               0.000923
# 493             0.000009
# 463             0.000002

# %%
parsed_df.sort_values("AUPR", ascending=False).head(3)
# Out:
#                    ACC               AUPR              AUROC  \
# 463  0.4725 (± 0.0671)    0.5608 (± 0.07)   0.514 (± 0.0295)
# 481  0.4651 (± 0.0714)  0.5575 (± 0.0667)  0.5111 (± 0.0293)
# 694  0.4615 (± 0.0703)  0.5562 (± 0.0741)  0.5109 (± 0.0313)
#
#           Balanced_ACC                 F1             Recall  \
# 463   0.5039 (± 0.009)  0.1232 (± 0.2301)  0.1412 (± 0.3126)
# 481  0.5015 (± 0.0072)  0.0822 (± 0.2061)  0.0981 (± 0.2684)
# 694  0.5023 (± 0.0077)  0.0837 (± 0.2055)  0.1039 (± 0.2786)
#
#              Precision  params_T_max params_activation  params_dropout1  \
# 463  0.3049 (± 0.3587)           NaN              relu             0.15
# 481  0.1512 (± 0.2891)          25.0              gelu             0.45
# 694  0.1928 (± 0.3174)           NaN              gelu             0.35
#
#      params_dropout2  params_heads  params_hidden1  params_hidden2  \
# 463             0.25             3             315             152
# 481             0.50             2             561             242
# 694             0.25             3             391             142
#
#      params_hidden3  params_lr params_optimizer params_scheduler  \
# 463             141   0.000994             Adam             None
# 481             226   0.001432             Adam           Cosine
# 694              93   0.002605             Adam             None
#
#      params_weight_decay
# 463             0.000002
# 481             0.000323
# 694             0.000024

# %%
parsed_df.sort_values("AUROC", ascending=False).head(3)
# Out:
#                    ACC               AUPR              AUROC  \
# 463  0.4725 (± 0.0671)    0.5608 (± 0.07)   0.514 (± 0.0295)
# 675  0.4607 (± 0.0688)  0.5561 (± 0.0649)   0.513 (± 0.0227)
# 481  0.4651 (± 0.0714)  0.5575 (± 0.0667)  0.5111 (± 0.0293)
#
#           Balanced_ACC                 F1             Recall  \
# 463   0.5039 (± 0.009)  0.1232 (± 0.2301)  0.1412 (± 0.3126)
# 675  0.4997 (± 0.0022)  0.0359 (± 0.1319)  0.0377 (± 0.1624)
# 481  0.5015 (± 0.0072)  0.0822 (± 0.2061)  0.0981 (± 0.2684)
#
#              Precision  params_T_max params_activation  params_dropout1  \
# 463  0.3049 (± 0.3587)           NaN              relu             0.15
# 675  0.0621 (± 0.1731)           NaN              gelu             0.25
# 481  0.1512 (± 0.2891)          25.0              gelu             0.45
#
#      params_dropout2  params_heads  params_hidden1  params_hidden2  \
# 463             0.25             3             315             152
# 675             0.40             3             531              69
# 481             0.50             2             561             242
#
#      params_hidden3  params_lr params_optimizer params_scheduler  \
# 463             141   0.000994             Adam             None
# 675              44   0.003638            AdamW             None
# 481             226   0.001432             Adam           Cosine
#
#      params_weight_decay
# 463             0.000002
# 675             0.001064
# 481             0.000323

# %%
method = "Transformer"
study = optuna.create_study(
    storage=f"sqlite:///{method}_{task}_small.sqlite3",
    study_name=method,
    load_if_exists=True,
)
tmp = study.trials_dataframe().dropna(
    subset=["values_0", "values_1", "values_2", "values_3"]
)
tmp = tmp[[i for i in tmp.columns if "params" in i]]
df = (
    study.trials_dataframe()
    .dropna(subset=["values_0", "values_1", "values_2", "values_3"])
    .iloc[:, 20:-2]
)
df.columns = [i.replace("user_attrs_", "") for i in df.columns]

print(df.shape)
n = df.shape[0]
if n > 0:
    parsed_df = get_parsed_df(df)
    parsed_df = pd.concat([parsed_df, tmp], axis=1)
    parsed_df.sort_values("AUPR", ascending=False).head()
# Out:
# [I 2025-04-15 13:36:42,295] Using an existing study with name 'Transformer' instead of creating a new one.
# (62, 22)

# %%
parsed_df.sort_values("ACC", ascending=False).head(3)
# Out:
#                    ACC               AUPR              AUROC  \
# 383   0.521 (± 0.0713)  0.5749 (± 0.0733)  0.5219 (± 0.0438)
# 598  0.5183 (± 0.0813)    0.5976 (± 0.12)  0.5472 (± 0.0862)
# 668  0.5142 (± 0.0709)  0.5782 (± 0.0811)  0.5262 (± 0.0415)
#
#           Balanced_ACC                 F1             Recall  \
# 383  0.5034 (± 0.0156)  0.3561 (± 0.3429)   0.457 (± 0.4626)
# 598  0.5082 (± 0.0433)  0.3077 (± 0.2848)   0.3234 (± 0.385)
# 668  0.5046 (± 0.0184)   0.347 (± 0.3342)  0.4416 (± 0.4598)
#
#              Precision  params_T_max params_activation  params_dropout1  \
# 383  0.3599 (± 0.3008)          21.0              gelu             0.15
# 598  0.5643 (± 0.2783)           NaN              relu             0.15
# 668  0.4029 (± 0.3002)           NaN              gelu             0.35
#
#      params_dropout2  params_heads  params_hidden1  params_hidden2  \
# 383             0.45             7             534              81
# 598             0.20             3             564             108
# 668             0.20             2             314             250
#
#      params_hidden3  params_lr params_optimizer params_scheduler  \
# 383              40   0.001147             Adam           Cosine
# 598              46   0.000016             Adam             None
# 668              34   0.000334            AdamW             None
#
#      params_weight_decay
# 383             0.000223
# 598             0.000576
# 668             0.000322

# %%
parsed_df.sort_values("AUPR", ascending=False).head(3)
# Out:
#                    ACC               AUPR              AUROC  \
# 619  0.5097 (± 0.0698)  0.6041 (± 0.1228)  0.5491 (± 0.0999)
# 62   0.5038 (± 0.0693)  0.6014 (± 0.1201)  0.5495 (± 0.0945)
# 2    0.5093 (± 0.0712)    0.6014 (± 0.12)  0.5467 (± 0.0945)
#
#           Balanced_ACC                 F1             Recall  \
# 619  0.5028 (± 0.0402)   0.3423 (± 0.301)  0.3949 (± 0.4193)
# 62   0.5103 (± 0.0488)  0.3054 (± 0.2653)  0.3163 (± 0.3671)
# 2    0.5089 (± 0.0424)  0.3332 (± 0.3049)  0.3916 (± 0.4235)
#
#              Precision  params_T_max params_activation  params_dropout1  \
# 619  0.5001 (± 0.2876)           NaN              gelu              0.2
# 62   0.5443 (± 0.2745)           NaN              relu              0.2
# 2     0.534 (± 0.3032)           NaN              gelu              0.2
#
#      params_dropout2  params_heads  params_hidden1  params_hidden2  \
# 619              0.2             2             918             218
# 62               0.2             6             531              83
# 2                0.1             7             410              72
#
#      params_hidden3  params_lr params_optimizer params_scheduler  \
# 619             139   0.000042            AdamW             None
# 62               32   0.000037             Adam             None
# 2                42   0.000143            AdamW             None
#
#      params_weight_decay
# 619             0.000501
# 62              0.000878
# 2               0.000140

# %%
parsed_df.sort_values("AUROC", ascending=False).head(3)
# Out:
#                    ACC               AUPR              AUROC  \
# 62   0.5038 (± 0.0693)  0.6014 (± 0.1201)  0.5495 (± 0.0945)
# 619  0.5097 (± 0.0698)  0.6041 (± 0.1228)  0.5491 (± 0.0999)
# 598  0.5183 (± 0.0813)    0.5976 (± 0.12)  0.5472 (± 0.0862)
#
#           Balanced_ACC                 F1             Recall  \
# 62   0.5103 (± 0.0488)  0.3054 (± 0.2653)  0.3163 (± 0.3671)
# 619  0.5028 (± 0.0402)   0.3423 (± 0.301)  0.3949 (± 0.4193)
# 598  0.5082 (± 0.0433)  0.3077 (± 0.2848)   0.3234 (± 0.385)
#
#              Precision  params_T_max params_activation  params_dropout1  \
# 62   0.5443 (± 0.2745)           NaN              relu             0.20
# 619  0.5001 (± 0.2876)           NaN              gelu             0.20
# 598  0.5643 (± 0.2783)           NaN              relu             0.15
#
#      params_dropout2  params_heads  params_hidden1  params_hidden2  \
# 62               0.2             6             531              83
# 619              0.2             2             918             218
# 598              0.2             3             564             108
#
#      params_hidden3  params_lr params_optimizer params_scheduler  \
# 62               32   0.000037             Adam             None
# 619             139   0.000042            AdamW             None
# 598              46   0.000016             Adam             None
#
#      params_weight_decay
# 62              0.000878
# 619             0.000501
# 598             0.000576

# %%
method = "GAT"
study = optuna.create_study(
    storage=f"sqlite:///{method}_{task}_small.sqlite3",
    study_name=method,
    load_if_exists=True,
)
tmp = study.trials_dataframe().dropna(
    subset=["values_0", "values_1", "values_2", "values_3"]
)
tmp = tmp[[i for i in tmp.columns if "params" in i]]
df = (
    study.trials_dataframe()
    .dropna(subset=["values_0", "values_1", "values_2", "values_3"])
    .iloc[:, 20:-2]
)
df.columns = [i.replace("user_attrs_", "") for i in df.columns]

print(df.shape)
n = df.shape[0]
if n > 0:
    parsed_df = get_parsed_df(df)
    parsed_df = pd.concat([parsed_df, tmp], axis=1)
    parsed_df.sort_values("AUPR", ascending=False).head()

parsed_df.head() if n > 0 else None
# Out:
# [I 2025-04-15 13:36:43,235] Using an existing study with name 'GAT' instead of creating a new one.
# (1752, 22)
#                   ACC               AUPR              AUROC  \
# 2    0.495 (± 0.0736)  0.5373 (± 0.0776)  0.4889 (± 0.0311)
# 3   0.4948 (± 0.0735)  0.5474 (± 0.0712)  0.5027 (± 0.0258)
# 4   0.4961 (± 0.0723)  0.5489 (± 0.0721)  0.5016 (± 0.0293)
# 10  0.4739 (± 0.0735)    0.5443 (± 0.07)  0.4981 (± 0.0314)
# 27  0.4973 (± 0.0747)  0.5504 (± 0.0713)  0.5053 (± 0.0265)
#
#          Balanced_ACC                 F1             Recall  \
# 2   0.4956 (± 0.0124)   0.3762 (± 0.322)  0.4957 (± 0.4608)
# 3   0.5032 (± 0.0109)  0.3504 (± 0.3113)   0.4369 (± 0.434)
# 4   0.5035 (± 0.0132)  0.4021 (± 0.3096)   0.5312 (± 0.462)
# 10  0.4993 (± 0.0074)  0.2042 (± 0.3022)  0.2732 (± 0.4277)
# 27  0.4981 (± 0.0144)  0.3468 (± 0.3184)  0.4356 (± 0.4414)
#
#             Precision  params_T_max params_activation  params_dropout1  \
# 2   0.4081 (± 0.2526)           NaN              relu             0.40
# 3   0.4338 (± 0.2644)           1.0              gelu             0.45
# 4   0.4819 (± 0.2167)           NaN              gelu             0.50
# 10  0.2194 (± 0.2713)           1.0              relu             0.40
# 27  0.4006 (± 0.2639)           1.0              gelu             0.50
#
#     params_dropout2  params_heads  params_hidden1  params_hidden2  \
# 2              0.35             3             353              76
# 3              0.30             2             661             134
# 4              0.10             2             694             152
# 10             0.15             3             260             168
# 27             0.45             3             876             179
#
#     params_hidden3  params_lr params_optimizer params_scheduler  \
# 2               52   0.000020            AdamW             None
# 3               99   0.001456            AdamW           Cosine
# 4              113   0.000303            AdamW             None
# 10             108   0.002978             Adam           Cosine
# 27             108   0.004021             Adam           Cosine
#
#     params_weight_decay
# 2              0.000010
# 3              0.000063
# 4              0.000207
# 10             0.000001
# 27             0.000015

# %%
parsed_df.sort_values("ACC", ascending=False).head(3)
# Out:
#                     ACC               AUPR              AUROC  \
# 3889  0.5257 (± 0.0727)   0.545 (± 0.0684)  0.4979 (± 0.0305)
# 844   0.5231 (± 0.0722)  0.5421 (± 0.0698)  0.4952 (± 0.0255)
# 2717  0.5213 (± 0.0637)  0.5444 (± 0.0712)   0.499 (± 0.0281)
#
#            Balanced_ACC                 F1             Recall  \
# 3889  0.4999 (± 0.0108)  0.3947 (± 0.3431)  0.5231 (± 0.4824)
# 844   0.5001 (± 0.0148)  0.4205 (± 0.3356)  0.5602 (± 0.4727)
# 2717  0.5007 (± 0.0124)  0.4727 (± 0.3055)  0.6202 (± 0.4365)
#
#               Precision  params_T_max params_activation  params_dropout1  \
# 3889   0.415 (± 0.2632)           2.0              relu             0.20
# 844   0.4314 (± 0.2364)           2.0              gelu             0.35
# 2717  0.4574 (± 0.2256)           2.0              gelu             0.30
#
#       params_dropout2  params_heads  params_hidden1  params_hidden2  \
# 3889             0.15             2             418             120
# 844              0.10             2             400             258
# 2717             0.40             2             342             106
#
#       params_hidden3  params_lr params_optimizer params_scheduler  \
# 3889              33   0.000052             Adam           Cosine
# 844               85   0.000974             Adam           Cosine
# 2717              98   0.000052             Adam           Cosine
#
#       params_weight_decay
# 3889             0.000003
# 844              0.000003
# 2717             0.000016

# %%
parsed_df.sort_values("AUPR", ascending=False).head(3)
# Out:
#                     ACC               AUPR              AUROC  \
# 3779  0.4947 (± 0.0781)  0.5553 (± 0.0689)  0.5108 (± 0.0229)
# 3769  0.4809 (± 0.0726)   0.555 (± 0.0762)  0.5113 (± 0.0316)
# 1879    0.493 (± 0.076)  0.5548 (± 0.0721)   0.5106 (± 0.029)
#
#            Balanced_ACC                 F1             Recall  \
# 3779   0.504 (± 0.0138)  0.3449 (± 0.3327)  0.4647 (± 0.4769)
# 3769  0.5023 (± 0.0128)  0.3296 (± 0.3175)  0.4401 (± 0.4659)
# 1879  0.5026 (± 0.0121)   0.3077 (± 0.315)  0.3912 (± 0.4511)
#
#               Precision  params_T_max params_activation  params_dropout1  \
# 3779  0.3839 (± 0.2657)           NaN              gelu             0.15
# 3769  0.3976 (± 0.2773)           1.0              gelu             0.30
# 1879  0.3887 (± 0.2749)           2.0              relu             0.35
#
#       params_dropout2  params_heads  params_hidden1  params_hidden2  \
# 3779             0.25             3             502             157
# 3769             0.45             2             698             191
# 1879             0.25             3             361             167
#
#       params_hidden3  params_lr params_optimizer params_scheduler  \
# 3779              78   0.000016            AdamW             None
# 3769             178   0.000052             Adam           Cosine
# 1879             112   0.000074            AdamW           Cosine
#
#       params_weight_decay
# 3779             0.000161
# 3769             0.000016
# 1879             0.000126

# %%
parsed_df.sort_values("AUROC", ascending=False).head(3)
# Out:
#                     ACC               AUPR              AUROC  \
# 3769  0.4809 (± 0.0726)   0.555 (± 0.0762)  0.5113 (± 0.0316)
# 721   0.4934 (± 0.0757)  0.5533 (± 0.0729)  0.5108 (± 0.0298)
# 3779  0.4947 (± 0.0781)  0.5553 (± 0.0689)  0.5108 (± 0.0229)
#
#            Balanced_ACC                 F1             Recall  \
# 3769  0.5023 (± 0.0128)  0.3296 (± 0.3175)  0.4401 (± 0.4659)
# 721   0.5045 (± 0.0139)    0.335 (± 0.313)  0.4271 (± 0.4548)
# 3779   0.504 (± 0.0138)  0.3449 (± 0.3327)  0.4647 (± 0.4769)
#
#               Precision  params_T_max params_activation  params_dropout1  \
# 3769  0.3976 (± 0.2773)           1.0              gelu             0.30
# 721   0.4157 (± 0.2583)           NaN              gelu             0.45
# 3779  0.3839 (± 0.2657)           NaN              gelu             0.15
#
#       params_dropout2  params_heads  params_hidden1  params_hidden2  \
# 3769             0.45             2             698             191
# 721              0.10             2             342             199
# 3779             0.25             3             502             157
#
#       params_hidden3  params_lr params_optimizer params_scheduler  \
# 3769             178   0.000052             Adam           Cosine
# 721              159   0.000108            AdamW             None
# 3779              78   0.000016            AdamW             None
#
#       params_weight_decay
# 3769             0.000016
# 721              0.000003
# 3779             0.000161

# %%
method = "MPNN"
study = optuna.create_study(
    storage=f"sqlite:///{method}_{task}_small.sqlite3",
    study_name=method,
    load_if_exists=True,
)
tmp = study.trials_dataframe().dropna(
    subset=["values_0", "values_1", "values_2", "values_3"]
)
tmp = tmp[[i for i in tmp.columns if "params" in i]]
df = (
    study.trials_dataframe()
    .dropna(subset=["values_0", "values_1", "values_2", "values_3"])
    .iloc[:, 19:-2]
)
df.columns = [i.replace("user_attrs_", "") for i in df.columns]

print(df.shape)
n = df.shape[0]
if n > 0:
    parsed_df = get_parsed_df(df)
    parsed_df = pd.concat([parsed_df, tmp], axis=1)
    parsed_df.sort_values("AUPR", ascending=False).head()

parsed_df if n > 0 else None
# Out:
# [I 2025-04-15 13:36:48,342] Using an existing study with name 'MPNN' instead of creating a new one.
# (128, 23)
#                    ACC               AUPR              AUROC  \
# 1     0.4578 (± 0.066)  0.5476 (± 0.0716)  0.5022 (± 0.0283)
# 2     0.4582 (± 0.068)  0.5513 (± 0.0696)  0.5058 (± 0.0282)
# 4    0.4589 (± 0.0681)   0.549 (± 0.0679)  0.5023 (± 0.0285)
# 6    0.4568 (± 0.0665)  0.5496 (± 0.0695)    0.504 (± 0.029)
# 8    0.4564 (± 0.0672)  0.5485 (± 0.0703)  0.5035 (± 0.0236)
# ..                 ...                ...                ...
# 157  0.4644 (± 0.0694)  0.5493 (± 0.0697)  0.5047 (± 0.0223)
# 158  0.4571 (± 0.0665)  0.5486 (± 0.0645)  0.5022 (± 0.0277)
# 159  0.4598 (± 0.0689)  0.5517 (± 0.0668)  0.5054 (± 0.0279)
# 161  0.4573 (± 0.0662)  0.5469 (± 0.0681)  0.5013 (± 0.0276)
# 162  0.4761 (± 0.0753)   0.547 (± 0.0681)  0.4998 (± 0.0257)
#
#           Balanced_ACC                 F1             Recall  \
# 1    0.5005 (± 0.0066)   0.0115 (± 0.027)  0.0061 (± 0.0145)
# 2    0.5004 (± 0.0049)  0.0177 (± 0.0775)  0.0146 (± 0.0809)
# 4     0.4991 (± 0.005)   0.039 (± 0.1483)  0.0498 (± 0.2066)
# 6    0.4996 (± 0.0023)  0.0056 (± 0.0143)  0.0029 (± 0.0075)
# 8    0.4997 (± 0.0021)  0.0013 (± 0.0059)  0.0007 (± 0.0031)
# ..                 ...                ...                ...
# 157  0.4997 (± 0.0047)  0.0522 (± 0.1651)  0.0591 (± 0.2129)
# 158  0.4998 (± 0.0038)  0.0082 (± 0.0179)  0.0043 (± 0.0093)
# 159   0.4998 (± 0.003)  0.0301 (± 0.1266)   0.0366 (± 0.179)
# 161  0.4995 (± 0.0046)  0.0355 (± 0.1212)  0.0395 (± 0.1743)
# 162  0.4995 (± 0.0113)  0.1462 (± 0.2655)  0.1827 (± 0.3652)
#
#              Precision  params_T_max params_activation  params_dropout1  \
# 1    0.2267 (± 0.3555)           NaN              relu             0.15
# 2    0.1518 (± 0.2812)           NaN              gelu             0.10
# 4    0.1222 (± 0.2481)          26.0              gelu             0.20
# 6     0.1139 (± 0.272)           NaN              gelu             0.10
# 8    0.0425 (± 0.1681)           NaN              relu             0.45
# ..                 ...           ...               ...              ...
# 157  0.2057 (± 0.3097)          32.0              gelu             0.20
# 158  0.1692 (± 0.2886)           NaN              gelu             0.30
# 159  0.1937 (± 0.3061)          27.0              gelu             0.20
# 161  0.2223 (± 0.3118)           NaN              gelu             0.10
# 162  0.2925 (± 0.2892)           NaN              gelu             0.10
#
#      params_dropout2  params_heads  params_hidden1  params_hidden2  \
# 1               0.45             3             772             342
# 2               0.10             7             339             282
# 4               0.45             2             459             333
# 6               0.15             4             505             494
# 8               0.40             5             817             410
# ..               ...           ...             ...             ...
# 157             0.45             2             314             278
# 158             0.20             6             384              95
# 159             0.45             2             459             305
# 161             0.10             4             339              99
# 162             0.45             8             296              89
#
#      params_hidden3  params_lr params_optimizer params_scheduler  \
# 1               112   0.000031            AdamW             None
# 2                58   0.000041             Adam             None
# 4                47   0.000103            AdamW           Cosine
# 6               186   0.000023            AdamW             None
# 8               113   0.000187            AdamW             None
# ..              ...        ...              ...              ...
# 157              49   0.000049            AdamW           Cosine
# 158              65   0.000176             Adam             None
# 159              45   0.000103            AdamW           Cosine
# 161              58   0.000041             Adam             None
# 162              60   0.000015             Adam             None
#
#      params_weight_decay
# 1               0.000079
# 2               0.001111
# 4               0.000797
# 6               0.000009
# 8               0.000001
# ..                   ...
# 157             0.000012
# 158             0.000071
# 159             0.000797
# 161             0.000082
# 162             0.000082
#
# [128 rows x 19 columns]

# %%
parsed_df.sort_values("ACC", ascending=False).head(3)
# Out:
#                    ACC               AUPR              AUROC  \
# 113  0.4863 (± 0.0745)  0.5427 (± 0.0701)  0.4952 (± 0.0271)
# 84    0.4847 (± 0.075)  0.5457 (± 0.0705)  0.5003 (± 0.0263)
# 61   0.4817 (± 0.0716)  0.5471 (± 0.0735)   0.501 (± 0.0253)
#
#           Balanced_ACC                 F1             Recall  \
# 113  0.4984 (± 0.0113)  0.1783 (± 0.2789)  0.2114 (± 0.3767)
# 84   0.4994 (± 0.0107)  0.1885 (± 0.2832)  0.2263 (± 0.3857)
# 61     0.501 (± 0.011)  0.1767 (± 0.2748)  0.2138 (± 0.3807)
#
#              Precision  params_T_max params_activation  params_dropout1  \
# 113  0.3697 (± 0.3012)          20.0              gelu              0.5
# 84   0.3973 (± 0.2958)          32.0              gelu              0.1
# 61   0.4047 (± 0.3056)           NaN              relu              0.2
#
#      params_dropout2  params_heads  params_hidden1  params_hidden2  \
# 113             0.50             5             380              82
# 84              0.45             2             602              78
# 61              0.45             7             602             117
#
#      params_hidden3  params_lr params_optimizer params_scheduler  \
# 113              69   0.000011             Adam           Cosine
# 84               73   0.000012             Adam           Cosine
# 61               37   0.000012             Adam             None
#
#      params_weight_decay
# 113             0.000007
# 84              0.000082
# 61              0.000807

# %%
parsed_df.sort_values("AUPR", ascending=False).head(3)
# Out:
#                    ACC               AUPR              AUROC  \
# 146  0.4577 (± 0.0671)  0.5545 (± 0.0655)  0.5096 (± 0.0286)
# 159  0.4598 (± 0.0689)  0.5517 (± 0.0668)  0.5054 (± 0.0279)
# 19    0.457 (± 0.0674)  0.5517 (± 0.0639)  0.5062 (± 0.0259)
#
#           Balanced_ACC                 F1             Recall  \
# 146  0.5003 (± 0.0049)  0.0152 (± 0.0261)    0.008 (± 0.014)
# 159   0.4998 (± 0.003)  0.0301 (± 0.1266)   0.0366 (± 0.179)
# 19   0.5002 (± 0.0014)  0.0028 (± 0.0104)  0.0015 (± 0.0054)
#
#              Precision  params_T_max params_activation  params_dropout1  \
# 146   0.249 (± 0.3251)          20.0              gelu             0.30
# 159  0.1937 (± 0.3061)          27.0              gelu             0.20
# 19   0.0717 (± 0.2237)           NaN              gelu             0.35
#
#      params_dropout2  params_heads  params_hidden1  params_hidden2  \
# 146             0.25             6             977             162
# 159             0.45             2             459             305
# 19              0.15             7             397             388
#
#      params_hidden3  params_lr params_optimizer params_scheduler  \
# 146             145   0.000063            AdamW           Cosine
# 159              45   0.000103            AdamW           Cosine
# 19              120   0.000057             Adam             None
#
#      params_weight_decay
# 146             0.000015
# 159             0.000797
# 19              0.000003

# %%
parsed_df.sort_values("AUROC", ascending=False).head(3)
# Out:
#                    ACC               AUPR              AUROC  \
# 146  0.4577 (± 0.0671)  0.5545 (± 0.0655)  0.5096 (± 0.0286)
# 41   0.4568 (± 0.0673)  0.5512 (± 0.0664)  0.5075 (± 0.0277)
# 63   0.4642 (± 0.0628)  0.5497 (± 0.0685)  0.5074 (± 0.0251)
#
#           Balanced_ACC                 F1             Recall  \
# 146  0.5003 (± 0.0049)  0.0152 (± 0.0261)    0.008 (± 0.014)
# 41   0.4999 (± 0.0025)  0.0063 (± 0.0149)  0.0033 (± 0.0078)
# 63   0.5014 (± 0.0065)  0.0637 (± 0.1519)  0.0593 (± 0.1854)
#
#              Precision  params_T_max params_activation  params_dropout1  \
# 146   0.249 (± 0.3251)          20.0              gelu             0.30
# 41    0.122 (± 0.2458)           NaN              gelu             0.10
# 63   0.2625 (± 0.2966)           NaN              relu             0.45
#
#      params_dropout2  params_heads  params_hidden1  params_hidden2  \
# 146             0.25             6             977             162
# 41              0.35             3             815             373
# 63              0.20             8             804             117
#
#      params_hidden3  params_lr params_optimizer params_scheduler  \
# 146             145   0.000063            AdamW           Cosine
# 41              154   0.000019             Adam             None
# 63               53   0.000053            AdamW             None
#
#      params_weight_decay
# 146             0.000015
# 41              0.000008
# 63              0.004787

# %%
for i in parsed_df["ACC"]:
    if "0.5" in i:
        print(i)

# %%
method = "GCN"
study = optuna.create_study(
    storage=f"sqlite:///{method}_{task}_small.sqlite3",
    study_name=method,
    load_if_exists=True,
)
tmp = study.trials_dataframe().dropna(
    subset=["values_0", "values_1", "values_2", "values_3"]
)
tmp = tmp[[i for i in tmp.columns if "params" in i]]
df = (
    study.trials_dataframe()
    .dropna(subset=["values_0", "values_1", "values_2", "values_3"])
    .iloc[:, 20:-2]
)
df.columns = [i.replace("user_attrs_", "") for i in df.columns]

print(df.shape)
n = df.shape[0]
if n > 0:
    parsed_df = get_parsed_df(df)
    parsed_df = pd.concat([parsed_df, tmp], axis=1)
    parsed_df.sort_values("AUPR", ascending=False).head()

parsed_df if n > 0 else None
# Out:
# [I 2025-04-15 13:36:49,012] Using an existing study with name 'GCN' instead of creating a new one.
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# File /data/inouey2/conda/envs/genex/lib/python3.10/site-packages/sqlalchemy/engine/cursor.py:1136, in CursorFetchStrategy.fetchall(self, result, dbapi_cursor)
#    1135 try:
# -> 1136     rows = dbapi_cursor.fetchall()
#    1137     result._soft_close()
#
# DatabaseError: database disk image is malformed
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# File /data/inouey2/conda/envs/genex/lib/python3.10/site-packages/optuna/storages/_rdb/storage.py:72, in _create_scoped_session(scoped_session, ignore_integrity_error)
#      71 try:
# ---> 72     yield session
#      73     session.commit()
#
# File /data/inouey2/conda/envs/genex/lib/python3.10/site-packages/optuna/storages/_rdb/storage.py:830, in RDBStorage._get_trials(self, study_id, states, excluded_trial_ids)
#     817 try:
#     818     trial_models = (
#     819         session.query(models.TrialModel)
#     820         .options(sqlalchemy_orm.selectinload(models.TrialModel.params))
#     821         .options(sqlalchemy_orm.selectinload(models.TrialModel.values))
#     822         .options(sqlalchemy_orm.selectinload(models.TrialModel.user_attributes))
#     823         .options(sqlalchemy_orm.selectinload(models.TrialModel.system_attributes))
#     824         .options(sqlalchemy_orm.selectinload(models.TrialModel.intermediate_values))
#     825         .filter(
#     826             models.TrialModel.trial_id.in_(trial_ids),
#     827             models.TrialModel.study_id == study_id,
#     828         )
#     829         .order_by(models.TrialModel.trial_id)
# --> 830         .all()
#     831     )
#     832 except sqlalchemy_exc.OperationalError as e:
#     833     # Likely exceeding the number of maximum allowed variables using IN.
#     834     # This number differ between database dialects. For SQLite for instance, see
#     835     # https://www.sqlite.org/limits.html and the section describing
#     836     # SQLITE_MAX_VARIABLE_NUMBER.
#
# File /data/inouey2/conda/envs/genex/lib/python3.10/site-packages/sqlalchemy/orm/query.py:2673, in Query.all(self)
#    2652 """Return the results represented by this :class:`_query.Query`
#    2653 as a list.
#    2654
#    (...)
#    2671     :meth:`_engine.Result.scalars` - v2 comparable method.
#    2672 """
# -> 2673 return self._iter().all()
#
# File /data/inouey2/conda/envs/genex/lib/python3.10/site-packages/sqlalchemy/engine/result.py:1769, in ScalarResult.all(self)
#    1762 """Return all scalar values in a sequence.
#    1763
#    1764 Equivalent to :meth:`_engine.Result.all` except that
#    (...)
#    1767
#    1768 """
# -> 1769 return self._allrows()
#
# File /data/inouey2/conda/envs/genex/lib/python3.10/site-packages/sqlalchemy/engine/result.py:548, in ResultInternal._allrows(self)
#     546 make_row = self._row_getter
# --> 548 rows = self._fetchall_impl()
#     549 made_rows: List[_InterimRowType[_R]]
#
# File /data/inouey2/conda/envs/genex/lib/python3.10/site-packages/sqlalchemy/engine/result.py:1676, in FilterResult._fetchall_impl(self)
#    1675 def _fetchall_impl(self) -> List[_InterimRowType[Row[Any]]]:
# -> 1676     return self._real_result._fetchall_impl()
#
# File /data/inouey2/conda/envs/genex/lib/python3.10/site-packages/sqlalchemy/engine/result.py:2270, in IteratorResult._fetchall_impl(self)
#    2269 try:
# -> 2270     return list(self.iterator)
#    2271 finally:
#
# File /data/inouey2/conda/envs/genex/lib/python3.10/site-packages/sqlalchemy/orm/loading.py:219, in instances.<locals>.chunks(size)
#     218 else:
# --> 219     fetch = cursor._raw_all_rows()
#     221 if single_entity:
#
# File /data/inouey2/conda/envs/genex/lib/python3.10/site-packages/sqlalchemy/engine/result.py:540, in ResultInternal._raw_all_rows(self)
#     539 assert make_row is not None
# --> 540 rows = self._fetchall_impl()
#     541 return [make_row(row) for row in rows]
#
# File /data/inouey2/conda/envs/genex/lib/python3.10/site-packages/sqlalchemy/engine/cursor.py:2135, in CursorResult._fetchall_impl(self)
#    2134 def _fetchall_impl(self):
# -> 2135     return self.cursor_strategy.fetchall(self, self.cursor)
#
# File /data/inouey2/conda/envs/genex/lib/python3.10/site-packages/sqlalchemy/engine/cursor.py:1140, in CursorFetchStrategy.fetchall(self, result, dbapi_cursor)
#    1139 except BaseException as e:
# -> 1140     self.handle_exception(result, dbapi_cursor, e)
#
# File /data/inouey2/conda/envs/genex/lib/python3.10/site-packages/sqlalchemy/engine/cursor.py:1081, in CursorFetchStrategy.handle_exception(self, result, dbapi_cursor, err)
#    1075 def handle_exception(
#    1076     self,
#    1077     result: CursorResult[Any],
#    1078     dbapi_cursor: Optional[DBAPICursor],
#    1079     err: BaseException,
#    1080 ) -> NoReturn:
# -> 1081     result.connection._handle_dbapi_exception(
#    1082         err, None, None, dbapi_cursor, result.context
#    1083     )
#
# File /data/inouey2/conda/envs/genex/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2353, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2352     assert sqlalchemy_exception is not None
# -> 2353     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2354 else:
#
# File /data/inouey2/conda/envs/genex/lib/python3.10/site-packages/sqlalchemy/engine/cursor.py:1136, in CursorFetchStrategy.fetchall(self, result, dbapi_cursor)
#    1135 try:
# -> 1136     rows = dbapi_cursor.fetchall()
#    1137     result._soft_close()
#
# DatabaseError: (sqlite3.DatabaseError) database disk image is malformed
# (Background on this error at: https://sqlalche.me/e/20/4xp6)
#
# The above exception was the direct cause of the following exception:
#
# StorageInternalError                      Traceback (most recent call last)
# Cell In[19], line 7
#       1 method = "GCN"
#       2 study = optuna.create_study(
#       3     storage=f"sqlite:///{method}_{task}_small.sqlite3",
#       4     study_name=method,
#       5     load_if_exists=True,
#       6 )
# ----> 7 tmp = study.trials_dataframe().dropna(
#       8     subset=["values_0", "values_1", "values_2", "values_3"]
#       9 )
#      10 tmp = tmp[[i for i in tmp.columns if "params" in i]]
#      11 df = (
#      12     study.trials_dataframe()
#      13     .dropna(subset=["values_0", "values_1", "values_2", "values_3"])
#      14     .iloc[:, 20:-2]
#      15 )
#
# File /data/inouey2/conda/envs/genex/lib/python3.10/site-packages/optuna/study/study.py:768, in Study.trials_dataframe(self, attrs, multi_index)
#     702 def trials_dataframe(
#     703     self,
#     704     attrs: tuple[str, ...] = (
#    (...)
#     715     multi_index: bool = False,
#     716 ) -> "pd.DataFrame":
#     717     """Export trials as a pandas DataFrame_.
#     718
#     719     The DataFrame_ provides various features to analyze studies. It is also useful to draw a
#    (...)
#     766         objective value as value.
#     767     """
# --> 768     return _dataframe._trials_dataframe(self, attrs, multi_index)
#
# File /data/inouey2/conda/envs/genex/lib/python3.10/site-packages/optuna/study/_dataframe.py:100, in _trials_dataframe(study, attrs, multi_index)
#      97 _imports.check()
#      99 # If no trials, return an empty dataframe.
# --> 100 if len(study.get_trials(deepcopy=False)) == 0:
#     101     return pd.DataFrame()
#     103 if "value" in attrs and study._is_multi_objective():
#
# File /data/inouey2/conda/envs/genex/lib/python3.10/site-packages/optuna/study/study.py:264, in Study.get_trials(self, deepcopy, states)
#     224 def get_trials(
#     225     self,
#     226     deepcopy: bool = True,
#     227     states: Container[TrialState] | None = None,
#     228 ) -> list[FrozenTrial]:
#     229     """Return all trials in the study.
#     230
#     231     The returned trials are ordered by trial number.
#    (...)
#     262         A list of :class:`~optuna.trial.FrozenTrial` objects.
#     263     """
# --> 264     return self._get_trials(deepcopy, states, use_cache=False)
#
# File /data/inouey2/conda/envs/genex/lib/python3.10/site-packages/optuna/study/study.py:284, in Study._get_trials(self, deepcopy, states, use_cache)
#     281         filtered_trials = trials
#     282     return copy.deepcopy(filtered_trials) if deepcopy else filtered_trials
# --> 284 return self._storage.get_all_trials(self._study_id, deepcopy=deepcopy, states=states)
#
# File /data/inouey2/conda/envs/genex/lib/python3.10/site-packages/optuna/storages/_cached_storage.py:221, in _CachedStorage.get_all_trials(self, study_id, deepcopy, states)
#     215 def get_all_trials(
#     216     self,
#     217     study_id: int,
#     218     deepcopy: bool = True,
#     219     states: Optional[Container[TrialState]] = None,
#     220 ) -> List[FrozenTrial]:
# --> 221     self._read_trials_from_remote_storage(study_id)
#     223     with self._lock:
#     224         study = self._studies[study_id]
#
# File /data/inouey2/conda/envs/genex/lib/python3.10/site-packages/optuna/storages/_cached_storage.py:242, in _CachedStorage._read_trials_from_remote_storage(self, study_id)
#     240     self._studies[study_id] = _StudyInfo()
#     241 study = self._studies[study_id]
# --> 242 trials = self._backend._get_trials(
#     243     study_id, states=None, excluded_trial_ids=study.finished_trial_ids
#     244 )
#     245 if trials:
#     246     self._add_trials_to_cache(study_id, trials)
#
# File /data/inouey2/conda/envs/genex/lib/python3.10/site-packages/optuna/storages/_rdb/storage.py:797, in RDBStorage._get_trials(self, study_id, states, excluded_trial_ids)
#     791 def _get_trials(
#     792     self,
#     793     study_id: int,
#     794     states: Optional[Container[TrialState]],
#     795     excluded_trial_ids: Set[int],
#     796 ) -> List[FrozenTrial]:
# --> 797     with _create_scoped_session(self.scoped_session) as session:
#     798         # Ensure that the study exists.
#     799         models.StudyModel.find_or_raise_by_id(study_id, session)
#     800         query = session.query(models.TrialModel.trial_id).filter(
#     801             models.TrialModel.study_id == study_id
#     802         )
#
# File /data/inouey2/conda/envs/genex/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     151     value = typ()
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#     158     return exc is not value
#
# File /data/inouey2/conda/envs/genex/lib/python3.10/site-packages/optuna/storages/_rdb/storage.py:90, in _create_scoped_session(scoped_session, ignore_integrity_error)
#      84     session.rollback()
#      85     message = (
#      86         "An exception is raised during the commit. "
#      87         "This typically happens due to invalid data in the commit, "
#      88         "e.g. exceeding max length. "
#      89     )
# ---> 90     raise optuna.exceptions.StorageInternalError(message) from e
#      91 except Exception:
#      92     session.rollback()
#
# StorageInternalError: An exception is raised during the commit. This typically happens due to invalid data in the commit, e.g. exceeding max length.

# %%
for i in parsed_df["ACC"]:
    if "0.5" in i:
        print(i)

# %%
parsed_df.sort_values("ACC", ascending=False).head(3)

# %%
parsed_df.sort_values("AUPR", ascending=False).head(3)

# %%
parsed_df.sort_values("AUROC", ascending=False).head(3)
