# %%
import numpy as np
import pandas as pd

# %%
tmp = pd.read_csv("../DRBenchmark/NIHGCN/new_cell_true_nci.csv", index_col=0)

# %%
ttt = pd.read_csv("New_data/new_true_GAT_nci.csv", index_col=0)

# %%
for i in range(len(ttt)):
    if not np.alltrue(ttt.iloc[i].dropna() == tmp.iloc[i].dropna()):
        print(i)

# %%
# Out:
# True
