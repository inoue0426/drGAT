# %%
import optuna

# %%
name = "GDSC1_GAT"
study = optuna.create_study(
    storage="sqlite:///{}.sqlite3".format(name),
    study_name=name,
    load_if_exists=True,
)
res = study.trials_dataframe()
res.dropna(subset=[i for i in res.columns if "values" in i])
# Out:
# [I 2025-03-20 13:15:13,540] Using an existing study with name 'CTRP' instead of creating a new one.

# %%
name = "GDSC1"
study = optuna.create_study(
    storage="sqlite:///{}_{}.sqlite3".format(name, "GCN_MPNN"),
    study_name=name,
    load_if_exists=True,
)
res = study.trials_dataframe()
res.dropna(subset=[i for i in res.columns if "values" in i])
# Out:
# [I 2025-03-21 18:20:18,399] Using an existing study with name 'GDSC1' instead of creating a new one.
#     number  values_0  values_1  values_2  values_3             datetime_start  \
# 0        0  0.853783  0.947458  0.945834  0.840122 2025-03-21 18:13:21.033223
# 1        1  0.860070  0.950797  0.950630  0.848194 2025-03-21 18:13:21.038567
# 2        2  0.667637  0.932984  0.924931  0.505456 2025-03-21 18:13:21.042889
# 9        9  0.865076  0.948642  0.948125  0.854744 2025-03-21 18:13:23.199409
# 10      10  0.861932  0.952185  0.951129  0.850592 2025-03-21 18:13:23.532275
# 12      12  0.862165  0.947876  0.947202  0.851069 2025-03-21 18:13:24.913138
# 14      14  0.821537  0.944461  0.942897  0.794201 2025-03-21 18:13:41.286341
# 15      15  0.852736  0.949386  0.948533  0.838956 2025-03-21 18:13:41.974436
# 18      18  0.866123  0.949513  0.948403  0.856070 2025-03-21 18:13:53.061236
# 19      19  0.855530  0.950055  0.949420  0.842493 2025-03-21 18:13:58.393862
#
#             datetime_complete               duration  params_T_max  \
# 0  2025-03-21 18:13:41.050421 0 days 00:00:20.017198          28.0
# 1  2025-03-21 18:15:18.080777 0 days 00:01:57.042210           NaN
# 2  2025-03-21 18:13:41.241211 0 days 00:00:20.198322          29.0
# 9  2025-03-21 18:14:59.262323 0 days 00:01:36.062914           NaN
# 10 2025-03-21 18:14:30.263932 0 days 00:01:06.731657           NaN
# 12 2025-03-21 18:13:45.258089 0 days 00:00:20.344951           NaN
# 14 2025-03-21 18:13:58.317518 0 days 00:00:17.031177           NaN
# 15 2025-03-21 18:13:53.015474 0 days 00:00:11.041038           NaN
# 18 2025-03-21 18:15:20.075575 0 days 00:01:27.014339           NaN
# 19 2025-03-21 18:15:21.672645 0 days 00:01:23.278783           NaN
#
#    params_activation  ... params_momentum  params_nesterov  params_optimizer  \
# 0               relu  ...        0.872094             True               SGD
# 1              swish  ...             NaN              NaN              Adam
# 2               relu  ...             NaN              NaN             AdamW
# 9               gelu  ...        0.863424             True               SGD
# 10              gelu  ...             NaN              NaN             AdamW
# 12              gelu  ...             NaN              NaN             AdamW
# 14             swish  ...             NaN              NaN             AdamW
# 15              gelu  ...        0.906594            False               SGD
# 18              gelu  ...             NaN              NaN             AdamW
# 19              gelu  ...             NaN              NaN             AdamW
#
#     params_patience_plateau  params_scheduler  params_step_size  \
# 0                       NaN            Cosine               NaN
# 1                       4.0           Plateau               NaN
# 2                       NaN            Cosine               NaN
# 9                       NaN              None               NaN
# 10                      NaN              Step              24.0
# 12                      4.0           Plateau               NaN
# 14                      NaN              None               NaN
# 15                      NaN              Step              27.0
# 18                      4.0           Plateau               NaN
# 19                      4.0           Plateau               NaN
#
#    params_thresh_plateau  params_weight_decay  \
# 0                    NaN             0.000496
# 1               0.003882             0.000037
# 2                    NaN             0.001342
# 9                    NaN             0.000285
# 10                   NaN             0.000624
# 12              0.009597             0.000002
# 14                   NaN             0.008170
# 15                   NaN             0.000026
# 18              0.007346             0.000001
# 19              0.009838             0.000001
#
#     user_attrs_early_stopping_epoch     state
# 0                               NaN  COMPLETE
# 1                               NaN  COMPLETE
# 2                               NaN  COMPLETE
# 9                               NaN  COMPLETE
# 10                              NaN  COMPLETE
# 12                              NaN  COMPLETE
# 14                              NaN  COMPLETE
# 15                              NaN  COMPLETE
# 18                              NaN  COMPLETE
# 19                              NaN  COMPLETE
#
# [10 rows x 31 columns]
