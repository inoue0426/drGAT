# %%
import os
import sys

import optuna
import pandas as pd

current_dir = os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, ".."))
sys.path.append(parent_dir)

from metrics import get_parsed_df

# %%
task = 'drug'
method = "GATv2"
study = optuna.create_study(
    storage=f"sqlite:///{method}_{task}_small.sqlite3",
    study_name=method,
    load_if_exists=True,
)
tmp = study.trials_dataframe().dropna(
    subset=["values_0", "values_1", "values_2", "values_3"]
)
tmp = tmp[[i for i in tmp.columns if "params" in i]]
df = (
    study.trials_dataframe()
    .dropna(subset=["values_0", "values_1", "values_2", "values_3"])
    .iloc[:, 20:-2]
)
df.columns = [i.replace("user_attrs_", "") for i in df.columns]

print(df.shape)
n = df.shape[0]
if n > 0:
    parsed_df = get_parsed_df(df)
    parsed_df = pd.concat([parsed_df, tmp], axis=1)
    parsed_df.sort_values("AUPR", ascending=False).head()

# parsed_df if n > 0 else None
# Out:
# [I 2025-04-12 17:34:14,413] Using an existing study with name 'GATv2' instead of creating a new one.
# (0, 0)

# %%
parsed_df.sort_values('ACC', ascending=False).head(3)
# Out:
# KeyboardInterrupt

# %%
parsed_df.sort_values('AUPR', ascending=False).head(3)

# %%
parsed_df.sort_values('AUROC', ascending=False).head(3)

# %%
method = "Transformer"
study = optuna.create_study(
    storage=f"sqlite:///{method}_{task}_small.sqlite3",
    study_name=method,
    load_if_exists=True,
)
tmp = study.trials_dataframe().dropna(
    subset=["values_0", "values_1", "values_2", "values_3"]
)
tmp = tmp[[i for i in tmp.columns if "params" in i]]
df = (
    study.trials_dataframe()
    .dropna(subset=["values_0", "values_1", "values_2", "values_3"])
    .iloc[:, 20:-2]
)
df.columns = [i.replace("user_attrs_", "") for i in df.columns]

print(df.shape)
n = df.shape[0]
if n > 0:
    parsed_df = get_parsed_df(df)
    parsed_df = pd.concat([parsed_df, tmp], axis=1)
    parsed_df.sort_values("AUPR", ascending=False).head()

parsed_df if n > 0 else None
# Out:
# [I 2025-04-12 16:27:13,944] Using an existing study with name 'Transformer' instead of creating a new one.
# (0, 0)

# %%
parsed_df.sort_values('ACC', ascending=False).head(3)

# %%
parsed_df.sort_values('AUPR', ascending=False).head(3)

# %%
parsed_df.sort_values('AUROC', ascending=False).head(3)

# %%
method = "GAT"
study = optuna.create_study(
    storage=f"sqlite:///{method}_{task}_small.sqlite3",
    study_name=method,
    load_if_exists=True,
)
tmp = study.trials_dataframe().dropna(
    subset=["values_0", "values_1", "values_2", "values_3"]
)
tmp = tmp[[i for i in tmp.columns if "params" in i]]
df = (
    study.trials_dataframe()
    .dropna(subset=["values_0", "values_1", "values_2", "values_3"])
    .iloc[:, 20:-2]
)
df.columns = [i.replace("user_attrs_", "") for i in df.columns]

print(df.shape)
n = df.shape[0]
if n > 0:
    parsed_df = get_parsed_df(df)
    parsed_df = pd.concat([parsed_df, tmp], axis=1)
    parsed_df.sort_values("AUPR", ascending=False).head()

parsed_df if n > 0 else None
# Out:
# [I 2025-04-12 16:27:17,699] Using an existing study with name 'GAT' instead of creating a new one.
# (0, 0)

# %%
parsed_df.sort_values('ACC', ascending=False).head(3)

# %%
parsed_df.sort_values('AUPR', ascending=False).head(3)

# %%
parsed_df.sort_values('AUROC', ascending=False).head(3)

# %%
method = "MPNN"
study = optuna.create_study(
    storage=f"sqlite:///{method}_{task}_small.sqlite3",
    study_name=method,
    load_if_exists=True,
)
tmp = study.trials_dataframe().dropna(
    subset=["values_0", "values_1", "values_2", "values_3"]
)
tmp = tmp[[i for i in tmp.columns if "params" in i]]
df = (
    study.trials_dataframe()
    .dropna(subset=["values_0", "values_1", "values_2", "values_3"])
    .iloc[:, 19:-2]
)
df.columns = [i.replace("user_attrs_", "") for i in df.columns]

print(df.shape)
n = df.shape[0]
if n > 0:
    parsed_df = get_parsed_df(df)
    parsed_df = pd.concat([parsed_df, tmp], axis=1)
    parsed_df.sort_values("AUPR", ascending=False).head()

parsed_df.head() if n > 0 else None
# Out:
# [I 2025-04-12 16:27:20,110] Using an existing study with name 'MPNN' instead of creating a new one.
# (0, 1)

# %%
parsed_df.sort_values('ACC', ascending=False).head(3)

# %%
parsed_df.sort_values('AUPR', ascending=False).head(3)

# %%
parsed_df.sort_values('AUROC', ascending=False).head(3)

# %%
method = "GCN"
study = optuna.create_study(
    storage=f"sqlite:///{method}_{task}_small.sqlite3",
    study_name=method,
    load_if_exists=True,
)
tmp = study.trials_dataframe().dropna(
    subset=["values_0", "values_1", "values_2", "values_3"]
)
tmp = tmp[[i for i in tmp.columns if "params" in i]]
df = (
    study.trials_dataframe()
    .dropna(subset=["values_0", "values_1", "values_2", "values_3"])
    .iloc[:, 20:-2]
)
df.columns = [i.replace("user_attrs_", "") for i in df.columns]

print(df.shape)
n = df.shape[0]
if n > 0:
    parsed_df = get_parsed_df(df)
    parsed_df = pd.concat([parsed_df, tmp], axis=1)
    parsed_df.sort_values("AUPR", ascending=False).head()

parsed_df if n > 0 else None
# Out:
# [I 2025-04-12 16:27:23,831] Using an existing study with name 'GCN' instead of creating a new one.
# (0, 0)

# %%
parsed_df.sort_values('ACC', ascending=False).head(3)

# %%
parsed_df.sort_values('AUPR', ascending=False).head(3)

# %%
parsed_df.sort_values('AUROC', ascending=False).head(3)
