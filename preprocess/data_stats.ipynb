# %%
import numpy as np
import pandas as pd

from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
DATA_DIR = PROJECT_ROOT / "data"

# %% [markdown]
# # NCI

# %%
# データ読み込み
path = DATA_DIR / "nci_data"

# 各データセット
drugAct = pd.read_csv(path / "drugAct.csv", index_col=0).T
gene_exp_files = sorted(path.glob("gene_exp_part*.csv.gz"))
exprs = pd.concat([pd.read_csv(f, index_col=0) for f in gene_exp_files]).T.dropna()
mut = pd.concat([pd.read_csv(f, index_col=0) for f in sorted(path.glob("mut*"))]).T
met = pd.concat([pd.read_csv(f, index_col=0) for f in sorted(path.glob("met*"))]).T

# 共通細胞株
common_cells = set(drugAct.index) & set(exprs.index) & set(mut.index) & set(met.index)

# 統計取得関数
def get_stats(name, df):
    return {
        "Dataset": name,
        "Num Cells": int(df.shape[0]),
        "Num Features": int(df.shape[1]),
        "Missing Values": int(df.isna().sum().sum())
    }

# 各データセットの統計
stats = [
    get_stats("Gene Expression", exprs),
    get_stats("Mutation", mut),
    get_stats("Methylation", met),
    get_stats("Drug Activity", drugAct)
]

# 共通細胞株数の情報（NAを使う）
stats.append({
    "Dataset": "Common Cell Lines",
    "Num Cells": len(common_cells),
    "Num Features": pd.NA,
    "Missing Values": pd.NA
})

# DataFrame化し、型を明示
stats_df = pd.DataFrame(stats).astype({
    "Dataset": "string",
    "Num Cells": "int",
    "Num Features": "Int64",        # nullable integer
    "Missing Values": "Int64"
})
stats_df
# Out:
#              Dataset  Num Cells  Num Features  Missing Values
# 0    Gene Expression         60         23826               0
# 1           Mutation         60          9307               0
# 2        Methylation         60         17553             824
# 3      Drug Activity         60           977           44049
# 4  Common Cell Lines         60          <NA>            <NA>

# %% [markdown]
# # GDSC1

# %%
# データ読み込み
path = DATA_DIR / "gdsc1_data"

# 各データセット
drugAct = pd.read_csv(path / "drugAct.csv", index_col=0).T
gene_exp_files = sorted(path.glob("gene_exp_part*.csv.gz"))
exprs = pd.concat([pd.read_csv(f, index_col=0) for f in gene_exp_files]).T.dropna()
mut = pd.concat([pd.read_csv(f, index_col=0) for f in sorted(path.glob("mut*"))]).T
met = pd.concat([pd.read_csv(f, index_col=0) for f in sorted(path.glob("met*"))]).T

# 共通細胞株
common_cells = set(drugAct.index) & set(exprs.index) & set(mut.index) & set(met.index)

# 統計取得関数
def get_stats(name, df):
    return {
        "Dataset": name,
        "Num Cells": int(df.shape[0]),
        "Num Features": int(df.shape[1]),
        "Missing Values": int(df.isna().sum().sum())
    }

# 各データセットの統計
stats = [
    get_stats("Gene Expression", exprs),
    get_stats("Mutation", mut),
    get_stats("Methylation", met),
    get_stats("Drug Activity", drugAct)
]

# 共通細胞株数の情報（NAを使う）
stats.append({
    "Dataset": "Common Cell Lines",
    "Num Cells": len(common_cells),
    "Num Features": pd.NA,
    "Missing Values": pd.NA
})

# DataFrame化し、型を明示
stats_df = pd.DataFrame(stats).astype({
    "Dataset": "string",
    "Num Cells": "int",
    "Num Features": "Int64",        # nullable integer
    "Missing Values": "Int64"
})
stats_df
# Out:
#              Dataset  Num Cells  Num Features  Missing Values
# 0    Gene Expression        442         37263               0
# 1           Mutation       1084         18099         1321227
# 2        Methylation       1084         19864         2174189
# 3      Drug Activity        954           300          254319
# 4  Common Cell Lines        283          <NA>            <NA>

# %% [markdown]
# # GDSC2

# %%
# データ読み込み
path = DATA_DIR / "gdsc2_data"

# 各データセット
drugAct = pd.read_csv(path / "drugAct.csv", index_col=0).T
gene_exp_files = sorted(path.glob("gene_exp_part*.csv.gz"))
exprs = pd.concat([pd.read_csv(f, index_col=0) for f in gene_exp_files]).T.dropna()
mut = pd.concat([pd.read_csv(f, index_col=0) for f in sorted(path.glob("mut*"))]).T
met = pd.concat([pd.read_csv(f, index_col=0) for f in sorted(path.glob("met*"))]).T

# 共通細胞株
common_cells = set(drugAct.index) & set(exprs.index) & set(mut.index) & set(met.index)

# 統計取得関数
def get_stats(name, df):
    return {
        "Dataset": name,
        "Num Cells": int(df.shape[0]),
        "Num Features": int(df.shape[1]),
        "Missing Values": int(df.isna().sum().sum())
    }

# 各データセットの統計
stats = [
    get_stats("Gene Expression", exprs),
    get_stats("Mutation", mut),
    get_stats("Methylation", met),
    get_stats("Drug Activity", drugAct)
]

# 共通細胞株数の情報（NAを使う）
stats.append({
    "Dataset": "Common Cell Lines",
    "Num Cells": len(common_cells),
    "Num Features": pd.NA,
    "Missing Values": pd.NA
})

# DataFrame化し、型を明示
stats_df = pd.DataFrame(stats).astype({
    "Dataset": "string",
    "Num Cells": "int",
    "Num Features": "Int64",        # nullable integer
    "Missing Values": "Int64"
})
stats_df
# Out:
#              Dataset  Num Cells  Num Features  Missing Values
# 0    Gene Expression        442         37263               0
# 1           Mutation       1084         18099         1321227
# 2        Methylation       1084         19864         2174189
# 3      Drug Activity        661           153           90955
# 4  Common Cell Lines        194          <NA>            <NA>

# %% [markdown]
# # CTRP

# %%
# データ読み込み
path = DATA_DIR / "ctrp_data"

# 各データセット
drugAct = pd.read_csv(path / "drugAct.csv", index_col=0).T
gene_exp_files = sorted(path.glob("gene_exp_part*.csv.gz"))
exprs = pd.concat([pd.read_csv(f, index_col=0) for f in gene_exp_files]).T.dropna()
mut = pd.concat([pd.read_csv(f, index_col=0) for f in sorted(path.glob("mut*"))]).T
met = pd.concat([pd.read_csv(f, index_col=0) for f in sorted(path.glob("met*"))]).T

# 共通細胞株
common_cells = set(drugAct.index) & set(exprs.index) & set(mut.index) & set(met.index)

# 統計取得関数
def get_stats(name, df):
    return {
        "Dataset": name,
        "Num Cells": int(df.shape[0]),
        "Num Features": int(df.shape[1]),
        "Missing Values": int(df.isna().sum().sum())
    }

# 各データセットの統計
stats = [
    get_stats("Gene Expression", exprs),
    get_stats("Mutation", mut),
    get_stats("Methylation", met),
    get_stats("Drug Activity", drugAct)
]

# 共通細胞株数の情報（NAを使う）
stats.append({
    "Dataset": "Common Cell Lines",
    "Num Cells": len(common_cells),
    "Num Features": pd.NA,
    "Missing Values": pd.NA
})

# DataFrame化し、型を明示
stats_df = pd.DataFrame(stats).astype({
    "Dataset": "string",
    "Num Cells": "int",
    "Num Features": "Int64",        # nullable integer
    "Missing Values": "Int64"
})
stats_df
# Out:
#              Dataset  Num Cells  Num Features  Missing Values
# 0    Gene Expression       1019         52604               0
# 1           Mutation       1089          1667          320064
# 2        Methylation       1089         19880         5234995
# 3      Drug Activity        871           472          361162
# 4  Common Cell Lines        145          <NA>            <NA>
