# %%
import matplotlib.pyplot as plt
import pandas as pd
import venn

# %%
nci_cell = pd.read_csv("../nci_data/cell_sim.csv", index_col=0)
gdsc1_cell = pd.read_csv("../GDSC1_data/cell_sim.csv", index_col=0)
gdsc2_cell = pd.read_csv("../GDSC2_data/cell_sim.csv", index_col=0)
ctrp_cell = pd.read_csv("../CTRP_data/cell_sim.csv", index_col=0)

# %%
# インデックスの正規化関数


def normalize_index(index):
    return set(index.str.replace("-", "").str.replace("_", ""))


# 各データセットのインデックスを正規化
nci_normalized = normalize_index(nci_cell.index)
gdsc1_normalized = normalize_index(gdsc1_cell.index)
gdsc2_normalized = normalize_index(gdsc2_cell.index)
ctrp_normalized = normalize_index(ctrp_cell.index)

# %%
from collections import defaultdict
from itertools import combinations

# データセットを辞書で管理
datasets = {
    "NCI": nci_normalized,
    "GDSC1": gdsc1_normalized,
    "GDSC2": gdsc2_normalized,
    "CTRP": ctrp_normalized,
}


def get_hierarchical_overlaps(datasets):
    # 全細胞株の集合
    all_cells = set().union(*datasets.values())

    # 各細胞株が存在するデータセット数をカウント
    cell_counts = {
        cell: sum(cell in s for s in datasets.values()) for cell in all_cells
    }

    # 階層別分類用の辞書
    hierarchy = defaultdict(list)

    # 4つ全てに含まれる
    all_intersection = set.intersection(*datasets.values())
    hierarchy[4] = [("ALL", all_intersection)]

    # 3つに含まれる（組み合わせごと）
    for combo in combinations(datasets.keys(), 3):
        intersection = set.intersection(*[datasets[name] for name in combo])
        intersection -= all_intersection  # 4つ共通の要素を除外
        hierarchy[3].append((combo, intersection))

    # 2つに含まれる（組み合わせごと）
    for combo in combinations(datasets.keys(), 2):
        intersection = set.intersection(*[datasets[name] for name in combo])
        # 上位階層の要素を除外
        for higher in hierarchy[4] + hierarchy[3]:
            intersection -= higher[1]
        hierarchy[2].append((combo, intersection))

    # 1つにのみ含まれる
    unique_cells = all_cells - set().union(
        *[s for v in hierarchy.values() for _, s in v]
    )
    for name in datasets:
        cells = datasets[name] & unique_cells
        hierarchy[1].append(((name,), cells))

    return hierarchy


# 階層データを取得
hierarchy = get_hierarchical_overlaps(datasets)

# Convert hierarchical data to DataFrame
hierarchy_list = []
for count in [4, 3, 2, 1]:
    items = hierarchy[count]

    if count == 4:
        hierarchy_list.append(
            {
                "Number of Datasets": count,
                "Combination": "ALL",
                "Cell Line Count": len(items[0][1]),
                "Cell Line List": ", ".join(sorted(items[0][1])),
            }
        )
        continue

    for combo, cells in items:
        combo_name = " & ".join(combo) if count != 1 else combo[0]
        hierarchy_list.append(
            {
                "Number of Datasets": count,
                "Combination": combo_name,
                "Cell Line Count": len(cells),
                "Cell Line List": ", ".join(sorted(cells)),
            }
        )

# Create DataFrame
df = pd.DataFrame(hierarchy_list)

# Format table (group by dataset count)
pivot_df = df.pivot_table(
    index=["Number of Datasets", "Combination"],
    values=["Cell Line Count", "Cell Line List"],
    aggfunc={"Cell Line Count": "first", "Cell Line List": "first"},
).reset_index()

# Set display options
pd.set_option("display.max_colwidth", 100)

# %%
pivot_df
# .to_csv('cell_pivot.csv')
# Out:
#     Number of Datasets           Combination  Cell Line Count  \
# 0                    1                  CTRP                0
# 1                    1                 GDSC1              379
# 2                    1                 GDSC2                0
# 3                    1                   NCI                5
# 4                    2          GDSC1 & CTRP                0
# 5                    2         GDSC1 & GDSC2                0
# 6                    2          GDSC2 & CTRP              315
# 7                    2            NCI & CTRP                0
# 8                    2           NCI & GDSC1               19
# 9                    2           NCI & GDSC2                0
# 10                   3  GDSC1 & GDSC2 & CTRP              472
# 11                   3    NCI & GDSC1 & CTRP                0
# 12                   3   NCI & GDSC1 & GDSC2                0
# 13                   3    NCI & GDSC2 & CTRP                3
# ...

# %%
nci_cell = pd.read_csv("../nci_data/drug_sim.csv", index_col=0)
gdsc1_cell = pd.read_csv("../GDSC1_data/drug_sim.csv", index_col=0)
gdsc2_cell = pd.read_csv("../GDSC2_data/drug_sim.csv", index_col=0)
ctrp_cell = pd.read_csv("../CTRP_data/drug_sim.csv", index_col=0)

# %%
name = dict(
    pd.read_csv("../Figs/nsc_cid_smiles_class_name.csv", usecols=["NSC", "NAME"]).values
)
nci_cell.index = [name[i] for i in nci_cell.index]

# %%
# インデックスの正規化関数


def normalize_index(index):
    return set(index.str.replace("-", "").str.replace("_", ""))


# 各データセットのインデックスを正規化
nci_normalized = normalize_index(pd.Series([str(i) for i in nci_cell.index]))
gdsc1_normalized = normalize_index(gdsc1_cell.index)
gdsc2_normalized = normalize_index(gdsc2_cell.index)
ctrp_normalized = normalize_index(ctrp_cell.index)

# %%
from collections import defaultdict
from itertools import combinations

# データセットを辞書で管理
datasets = {
    "NCI": nci_normalized,
    "GDSC1": gdsc1_normalized,
    "GDSC2": gdsc2_normalized,
    "CTRP": ctrp_normalized,
}


def get_hierarchical_overlaps(datasets):
    # 全細胞株の集合
    all_cells = set().union(*datasets.values())

    # 各細胞株が存在するデータセット数をカウント
    cell_counts = {
        cell: sum(cell in s for s in datasets.values()) for cell in all_cells
    }

    # 階層別分類用の辞書
    hierarchy = defaultdict(list)

    # 4つ全てに含まれる
    all_intersection = set.intersection(*datasets.values())
    hierarchy[4] = [("ALL", all_intersection)]

    # 3つに含まれる（組み合わせごと）
    for combo in combinations(datasets.keys(), 3):
        intersection = set.intersection(*[datasets[name] for name in combo])
        intersection -= all_intersection  # 4つ共通の要素を除外
        hierarchy[3].append((combo, intersection))

    # 2つに含まれる（組み合わせごと）
    for combo in combinations(datasets.keys(), 2):
        intersection = set.intersection(*[datasets[name] for name in combo])
        # 上位階層の要素を除外
        for higher in hierarchy[4] + hierarchy[3]:
            intersection -= higher[1]
        hierarchy[2].append((combo, intersection))

    # 1つにのみ含まれる
    unique_cells = all_cells - set().union(
        *[s for v in hierarchy.values() for _, s in v]
    )
    for name in datasets:
        cells = datasets[name] & unique_cells
        hierarchy[1].append(((name,), cells))

    return hierarchy


# 階層データを取得
hierarchy = get_hierarchical_overlaps(datasets)

# Convert hierarchical data to DataFrame
hierarchy_list = []
for count in [4, 3, 2, 1]:
    items = hierarchy[count]

    if count == 4:
        hierarchy_list.append(
            {
                "Number of Datasets": count,
                "Combination": "ALL",
                "Cell Line Count": len(items[0][1]),
                "Cell Line List": ", ".join(sorted(items[0][1])),
            }
        )
        continue

    for combo, cells in items:
        combo_name = " & ".join(combo) if count != 1 else combo[0]
        hierarchy_list.append(
            {
                "Number of Datasets": count,
                "Combination": combo_name,
                "Cell Line Count": len(cells),
                "Cell Line List": ", ".join(sorted(cells)),
            }
        )

# Create DataFrame
df = pd.DataFrame(hierarchy_list)

# Format table (group by dataset count)
drug_pivot_df = df.pivot_table(
    index=["Number of Datasets", "Combination"],
    values=["Cell Line Count", "Cell Line List"],
    aggfunc={"Cell Line Count": "first", "Cell Line List": "first"},
).reset_index()

# Set display options
pd.set_option("display.max_colwidth", 100)

# %%
drug_pivot_df
# .to_csv('drug_pivot.csv')

# %%
nci_cell = pd.read_csv("../nci_data/gene_sim.csv", index_col=0)
gdsc1_cell = pd.read_csv("../GDSC1_data/gene_sim.csv", index_col=0)
gdsc2_cell = pd.read_csv("../GDSC2_data/gene_sim.csv", index_col=0)
ctrp_cell = pd.read_csv("../CTRP_data/gene_sim.csv", index_col=0)

# %%
# インデックスの正規化関数


def normalize_index(index):
    return set(index.str.replace("-", "").str.replace("_", ""))


# 各データセットのインデックスを正規化
nci_normalized = normalize_index(nci_cell.index)
gdsc1_normalized = normalize_index(gdsc1_cell.index)
gdsc2_normalized = normalize_index(gdsc2_cell.index)
ctrp_normalized = normalize_index(ctrp_cell.index)

# %%
from collections import defaultdict
from itertools import combinations

# データセットを辞書で管理
datasets = {
    "NCI": nci_normalized,
    "GDSC1": gdsc1_normalized,
    "GDSC2": gdsc2_normalized,
    "CTRP": ctrp_normalized,
}


def get_hierarchical_overlaps(datasets):
    # 全細胞株の集合
    all_cells = set().union(*datasets.values())

    # 各細胞株が存在するデータセット数をカウント
    cell_counts = {
        cell: sum(cell in s for s in datasets.values()) for cell in all_cells
    }

    # 階層別分類用の辞書
    hierarchy = defaultdict(list)

    # 4つ全てに含まれる
    all_intersection = set.intersection(*datasets.values())
    hierarchy[4] = [("ALL", all_intersection)]

    # 3つに含まれる（組み合わせごと）
    for combo in combinations(datasets.keys(), 3):
        intersection = set.intersection(*[datasets[name] for name in combo])
        intersection -= all_intersection  # 4つ共通の要素を除外
        hierarchy[3].append((combo, intersection))

    # 2つに含まれる（組み合わせごと）
    for combo in combinations(datasets.keys(), 2):
        intersection = set.intersection(*[datasets[name] for name in combo])
        # 上位階層の要素を除外
        for higher in hierarchy[4] + hierarchy[3]:
            intersection -= higher[1]
        hierarchy[2].append((combo, intersection))

    # 1つにのみ含まれる
    unique_cells = all_cells - set().union(
        *[s for v in hierarchy.values() for _, s in v]
    )
    for name in datasets:
        cells = datasets[name] & unique_cells
        hierarchy[1].append(((name,), cells))

    return hierarchy


# 階層データを取得
hierarchy = get_hierarchical_overlaps(datasets)

# Convert hierarchical data to DataFrame
hierarchy_list = []
for count in [4, 3, 2, 1]:
    items = hierarchy[count]

    if count == 4:
        hierarchy_list.append(
            {
                "Number of Datasets": count,
                "Combination": "ALL",
                "Cell Line Count": len(items[0][1]),
                "Cell Line List": ", ".join(sorted(items[0][1])),
            }
        )
        continue

    for combo, cells in items:
        combo_name = " & ".join(combo) if count != 1 else combo[0]
        hierarchy_list.append(
            {
                "Number of Datasets": count,
                "Combination": combo_name,
                "Cell Line Count": len(cells),
                "Cell Line List": ", ".join(sorted(cells)),
            }
        )

# Create DataFrame
df = pd.DataFrame(hierarchy_list)

# Format table (group by dataset count)
pivot_df = df.pivot_table(
    index=["Number of Datasets", "Combination"],
    values=["Cell Line Count", "Cell Line List"],
    aggfunc={"Cell Line Count": "first", "Cell Line List": "first"},
).reset_index()

# Set display options
pd.set_option("display.max_colwidth", 100)

# %%
pivot_df.to_csv("gene_pivot.csv")
