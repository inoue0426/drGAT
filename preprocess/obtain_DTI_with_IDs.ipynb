# %%
import ast
import concurrent.futures
import time

import pandas as pd
import requests
from tqdm import tqdm

# %%
df = pd.read_csv("drugbank.csv", index_col=0)
df.head()
# Out:
#              Drug Name DrugBank ID  PubChem CID  PubChem SID  \
# 0            Lepirudin     DB00001          NaN   46507011.0
# 1            Cetuximab     DB00002          NaN   46507042.0
# 2  Denileukin diftitox     DB00004          NaN   46506950.0
# 3           Etanercept     DB00005          NaN   46506732.0
# 4          Bivalirudin     DB00006   16129704.0   46507415.0
#
#                                               SMILES  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@...
#
#                                         Targets Name  \
# 0                                    ['Prothrombin']
# 1  ['Epidermal growth factor receptor', 'Low affi...
# 2  ['Interleukin-2 receptor subunit alpha', 'Inte...
# 3  ['Tumor necrosis factor', 'Lymphotoxin-alpha',...
# 4                                    ['Prothrombin']
#
#                                              Targets
# 0                                         ['P00734']
# 1  ['P00533', 'O75015', 'P02745', 'P02746', 'P027...
# 2                     ['P01589', 'P14784', 'P31785']
# 3  ['P01375', 'P01374', 'P12314', 'P12318', 'P319...
# 4                                         ['P00734']

# %%
df = (
    df.dropna(subset=["PubChem CID", "PubChem SID", "SMILES"], how="all")
    .drop(["Targets Name"], axis=1)
    .reset_index(drop=True)
)
df["Targets"] = df["Targets"].apply(ast.literal_eval)
df = df.explode("Targets")
df.shape
# Out:
# (18576, 6)

# %%
df.dropna(subset="PubChem CID")
# Out:
#                   Drug Name DrugBank ID  PubChem CID  PubChem SID  \
# 4               Bivalirudin     DB00006   16129704.0   46507415.0
# 12                Goserelin     DB00014    5311128.0   46507336.0
# 12                Goserelin     DB00014    5311128.0   46507336.0
# 43               Cetrorelix     DB00050   25074887.0   46505494.0
# 43               Cetrorelix     DB00050   25074887.0   46505494.0
# ...                     ...         ...          ...          ...
# 7441  Dexamethasone acetate     DB14649     236702.0          NaN
# 7441  Dexamethasone acetate     DB14649     236702.0          NaN
# 7441  Dexamethasone acetate     DB14649     236702.0          NaN
# 7441  Dexamethasone acetate     DB14649     236702.0          NaN
# 7496   Prednisolone acetate     DB15566       5834.0          NaN
#
#                                                  SMILES Targets
# 4     CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@...  P00734
# 12    CC(C)C[C@H](NC(=O)[C@@H](COC(C)(C)C)NC(=O)[C@H...  P22888
# 12    CC(C)C[C@H](NC(=O)[C@@H](COC(C)(C)C)NC(=O)[C@H...  P30968
# 43    CC(C)C[C@H](NC(=O)[C@@H](CCCNC(N)=O)NC(=O)[C@H...  P30968
# 43    CC(C)C[C@H](NC(=O)[C@@H](CCCNC(N)=O)NC(=O)[C@H...  P22888
# ...                                                 ...     ...
# 7441  [H][C@@]12C[C@@H](C)[C@](O)(C(=O)COC(C)=O)[C@@...  P04083
# 7441  [H][C@@]12C[C@@H](C)[C@](O)(C(=O)COC(C)=O)[C@@...  P35228
# 7441  [H][C@@]12C[C@@H](C)[C@](O)(C(=O)COC(C)=O)[C@@...  P51843
# 7441  [H][C@@]12C[C@@H](C)[C@](O)(C(=O)COC(C)=O)[C@@...  O75469
# 7496  [H][C@@]12CC[C@](O)(C(=O)COC(C)=O)[C@@]1(C)C[C...  P04150
#
# [16204 rows x 6 columns]

# %%
df.dropna(subset="PubChem SID")
# Out:
#                                       Drug Name DrugBank ID  PubChem CID  \
# 0                                     Lepirudin     DB00001          NaN
# 1                                     Cetuximab     DB00002          NaN
# 1                                     Cetuximab     DB00002          NaN
# 1                                     Cetuximab     DB00002          NaN
# 1                                     Cetuximab     DB00002          NaN
# ...                                         ...         ...          ...
# 7330  Equine Botulinum Neurotoxin D Immune FAB2     DB13902          NaN
# 7331  Equine Botulinum Neurotoxin B Immune FAB2     DB13903          NaN
# 7333                                  Volixibat     DB13914   24987688.0
# 7334                    Axicabtagene ciloleucel     DB13915          NaN
# 7335                                Candesartan     DB13919       2541.0
#
#       PubChem SID                                             SMILES Targets
# 0      46507011.0                                                NaN  P00734
# 1      46507042.0                                                NaN  P00533
# 1      46507042.0                                                NaN  O75015
# 1      46507042.0                                                NaN  P02745
# 1      46507042.0                                                NaN  P02746
# ...           ...                                                ...     ...
# 7330  347911471.0                                                NaN  P19321
# 7331  347911472.0                                                NaN  P10844
# 7333  347829333.0  [H][C@@]1([C@@H](O)[C@](CC)(CCCC)CS(=O)(=O)C2=...  Q12908
# 7334  347911476.0                                                NaN  P15391
# 7335  347829334.0  CCOC1=NC2=CC=CC(C(O)=O)=C2N1CC1=CC=C(C=C1)C1=C...  P30556
#
# [17153 rows x 6 columns]

# %%
df.dropna(subset="SMILES")
# Out:
#                                   Drug Name DrugBank ID  PubChem CID  \
# 4                               Bivalirudin     DB00006   16129704.0
# 5                                Leuprolide     DB00007          NaN
# 12                                Goserelin     DB00014    5311128.0
# 12                                Goserelin     DB00014    5311128.0
# 30                             Desmopressin     DB00035          NaN
# ...                                     ...         ...          ...
# 7561  Lutetium Lu-177 vipivotide tetraxetan     DB16778          NaN
# 7562                                 Indigo     DB16862          NaN
# 7563                             Linzagolix     DB17083          NaN
# 7564                                UCB7362     DB17096          NaN
# 7564                                UCB7362     DB17096          NaN
#
#       PubChem SID                                             SMILES Targets
# 4      46507415.0  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@...  P00734
# 5      46507635.0  CCNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=N)NC(=...  P30968
# 12     46507336.0  CC(C)C[C@H](NC(=O)[C@@H](COC(C)(C)C)NC(=O)[C@H...  P22888
# 12     46507336.0  CC(C)C[C@H](NC(=O)[C@@H](COC(C)(C)C)NC(=O)[C@H...  P30968
# 30            NaN  NC(=O)CC[C@@H]1NC(=O)[C@H](CC2=CC=CC=C2)NC(=O)...  P30518
# ...           ...                                                ...     ...
# 7561          NaN  [177Lu+3].OC(=O)CC[C@H](NC(=O)N[C@@H](CCCCNC(=...  P07288
# 7562          NaN        O=C1\C(NC2=C1C=CC=C2)=C1/NC2=C(C=CC=C2)C1=O  P35869
# 7563          NaN  COC1=C(COC2=C(OC)C=C(F)C(=C2)N2C(=O)NC3=CSC(C(...  P30968
# 7564          NaN  C[C@H]1C[C@H](CCO1)N1C(=O)C[C@](C)(NC1=N)C1=C(...  Q8IAS0
# 7564          NaN  C[C@H]1C[C@H](CCO1)N1C(=O)C[C@](C)(NC1=N)C1=C(...  W7JWW5
#
# [17523 rows x 6 columns]

# %%
tmp = pd.read_csv(
    "../../-code-drugbank_xml2csv_python/nsc_cid_smiles_mechanism_name_dbid.csv",
    index_col=0,
)
tmp = tmp.rename(columns={"CID": "PubChem CID", "Name": "Drug Name"})
tmp.head()
# Out:
#    NSC  PubChem CID                                   SMILES MECHANISM  \
# 0    1        11122                        CC1=CC(=O)C=CC1=O     Other
# 1   17       219123         CCCCCCCCCCCCCCCC1=C(C=CC(=C1)O)N     Other
# 2   89        92844               CN(C)CCC(=O)C1=CC=CC=C1.Cl     Other
# 3  185         6197  CC1CC(C(=O)C(C1)C(CC2CC(=O)NC(=O)C2)O)C     Other
# 4  185         6197  CC1CC(C(=O)C(C1)C(CC2CC(=O)NC(=O)C2)O)C     Other
#
#                                            Drug Name DrugBank ID
# 0              2-methylcyclohexa-2,5-diene-1,4-dione         NaN
# 1                         4-amino-3-pentadecylphenol         NaN
# 2  3-(dimethylamino)-1-phenylpropan-1-one;hydroch...         NaN
# 3  4-[(2R)-2-[(1S,3S,5S)-3,5-dimethyl-2-oxocycloh...         NaN
# 4  4-[(2R)-2-[(1S,3S,5S)-3,5-dimethyl-2-oxocycloh...         NaN

# %%
def run_job(ids):
    url = "https://rest.uniprot.org/idmapping/run"
    data = {"from": "UniProtKB_AC-ID", "to": "Gene_Name", "ids": ",".join(ids)}
    response = requests.post(url, data=data)
    response.raise_for_status()
    return response.json().get("jobId")


def get_results(job_id):
    url = f"https://rest.uniprot.org/idmapping/results/{job_id}"
    response = requests.get(url)
    response.raise_for_status()
    return response.json()


def process_batch(ids):
    job_id = run_job(ids)
    result_data = get_results(job_id)
    return pd.DataFrame(result_data["results"])


def parallel_id_mapping(tar, num_workers=4):
    res = pd.DataFrame()
    batches = [tar[i : i + 10] for i in range(0, len(tar), 10)]

    with tqdm(total=len(batches), desc="Processing batches") as pbar:
        with concurrent.futures.ThreadPoolExecutor(max_workers=num_workers) as executor:
            futures = [executor.submit(process_batch, batch) for batch in batches]

            for future in concurrent.futures.as_completed(futures):
                res = pd.concat([res, future.result()])
                pbar.update(1)

    return res


res = parallel_id_mapping(df["Targets"].unique())
# Out:
# Processing batches: 100%|█████████████████████████████████████████████████████████████| 472/472 [01:37<00:00,  4.85it/s]

# %%
res.columns = ["Targets", "Gene"]
res
# Out:
#    Targets    Gene
# 0   P14784   IL2RB
# 1   P31785   IL2RG
# 2   P01375     TNF
# 3   P01374     LTA
# 4   P31994  FCGR2B
# ..     ...     ...
# 5   Q504U8    EGFR
# 6   Q92952   KCNN1
# 7   Q9H2S1   KCNN2
# 8   Q8IAS0     PMX
# 0   W7JWW5     PMX
#
# [4566 rows x 2 columns]

# %%
df = df.merge(res).drop("Targets", axis=1).dropna(subset="Gene")
df
# Out:
#                                    Drug Name DrugBank ID  PubChem CID  \
# 0                                  Lepirudin     DB00001          NaN
# 1                                  Cetuximab     DB00002          NaN
# 2                                  Cetuximab     DB00002          NaN
# 3                                  Cetuximab     DB00002          NaN
# 4                                  Cetuximab     DB00002          NaN
# ...                                      ...         ...          ...
# 18302  Lutetium Lu-177 vipivotide tetraxetan     DB16778          NaN
# 18303                                 Indigo     DB16862          NaN
# 18304                             Linzagolix     DB17083          NaN
# 18305                                UCB7362     DB17096          NaN
# 18306                                UCB7362     DB17096          NaN
#
#        PubChem SID                                             SMILES    Gene
# 0       46507011.0                                                NaN      F2
# 1       46507042.0                                                NaN    EGFR
# 2       46507042.0                                                NaN  FCGR3B
# 3       46507042.0                                                NaN    C1QA
# 4       46507042.0                                                NaN    C1QB
# ...            ...                                                ...     ...
# 18302          NaN  [177Lu+3].OC(=O)CC[C@H](NC(=O)N[C@@H](CCCCNC(=...    KLK3
# 18303          NaN        O=C1\C(NC2=C1C=CC=C2)=C1/NC2=C(C=CC=C2)C1=O     AHR
# 18304          NaN  COC1=C(COC2=C(OC)C=C(F)C(=C2)N2C(=O)NC3=CSC(C(...   GNRHR
# 18305          NaN  C[C@H]1C[C@H](CCO1)N1C(=O)C[C@](C)(NC1=N)C1=C(...     PMX
# 18306          NaN  C[C@H]1C[C@H](CCO1)N1C(=O)C[C@](C)(NC1=N)C1=C(...     PMX
#
# [18307 rows x 6 columns]

# %%
final = (
    pd.concat(
        [
            df.merge(tmp[["DrugBank ID", "NSC"]].dropna(), how="left"),
            df.merge(tmp[["PubChem CID", "NSC"]].dropna(), how="left"),
            df.merge(tmp[["SMILES", "NSC"]].dropna(), how="left"),
            df.merge(tmp[["Drug Name", "NSC"]].dropna(), how="left"),
        ]
    )
    .drop_duplicates()
    .reset_index(drop=True)
)
# final.to_csv('../data/full_table.csv', index=False)
final
# Out:
#          Drug Name DrugBank ID  PubChem CID  PubChem SID  \
# 0        Lepirudin     DB00001          NaN   46507011.0
# 1        Cetuximab     DB00002          NaN   46507042.0
# 2        Cetuximab     DB00002          NaN   46507042.0
# 3        Cetuximab     DB00002          NaN   46507042.0
# 4        Cetuximab     DB00002          NaN   46507042.0
# ...            ...         ...          ...          ...
# 19495    Menadione     DB00170       4055.0   46505447.0
# 19496    Menadione     DB00170       4055.0   46505447.0
# 19497    Menadione     DB00170       4055.0   46505447.0
# 19498   Tributyrin     DB12709       6050.0  347828907.0
# 19499  Carbendazim     DB13009      25429.0  347829145.0
#
#                                  SMILES    Gene  NSC
# 0                                   NaN      F2  NaN
# 1                                   NaN    EGFR  NaN
# 2                                   NaN  FCGR3B  NaN
# 3                                   NaN    C1QA  NaN
# 4                                   NaN    C1QB  NaN
# ...                                 ...     ...  ...
# 19495         CC1=CC(=O)C2=CC=CC=C2C1=O    NQO2  NaN
# 19496         CC1=CC(=O)C2=CC=CC=C2C1=O    NQO1  NaN
# 19497         CC1=CC(=O)C2=CC=CC=C2C1=O   BGLAP  NaN
# 19498  CCCC(=O)OCC(COC(=O)CCC)OC(=O)CCC   CASP3  NaN
# 19499         COC(=O)NC1=NC2=CC=CC=C2N1     AHR  NaN
#
# [19500 rows x 7 columns]
