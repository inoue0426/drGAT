# %%
import os
import xml.etree.ElementTree as ET

import numpy as np
import pandas as pd
from tqdm import tqdm

# %%
# XMLファイルのパス
xml_file_path = os.path.join("../../Downloads/", "full database.xml")

# XMLファイルをパース
tree = ET.parse(xml_file_path)
root = tree.getroot()

# DrugBankのXML名前空間
namespace = "{http://www.drugbank.ca}"

# 結果を格納するリスト
drug_data_list = []

# 各薬物から必要な情報を抽出
for drug in tqdm(root.findall(f"{namespace}drug")):
    drug_info = {
        "Drug Name": (
            drug.find(f"{namespace}name").text
            if drug.find(f"{namespace}name") is not None
            else "N/A"
        ),
        "DrugBank ID": None,
        "PubChem CID": None,
        "PubChem SID": None,
        "SMILES": None,
        "InChIKey": None,
        "Targets Name": [],
        "Targets": [],
    }

    # DrugBank IDの抽出
    drug_id_element = drug.find(f"{namespace}drugbank-id[@primary='true']")
    if drug_id_element is not None:
        drug_info["DrugBank ID"] = drug_id_element.text

    # 'external-identifiers'セクションからPubChem CID、SIDの抽出
    external_identifiers = drug.find(f"{namespace}external-identifiers")
    if external_identifiers is not None:
        for identifier in external_identifiers:
            resource = identifier.find(f"{namespace}resource")
            id_value = identifier.find(f"{namespace}identifier")
            if resource is not None and id_value is not None:
                if resource.text == "PubChem Compound":
                    drug_info["PubChem CID"] = id_value.text
                elif resource.text == "PubChem Substance":
                    drug_info["PubChem SID"] = id_value.text

    # 'calculated-properties'セクションからSMILESとInChIKeyの抽出
    calculated_properties = drug.find(f"{namespace}calculated-properties")
    if calculated_properties is not None:
        for prop in calculated_properties:
            kind = prop.find(f"{namespace}kind")
            value = prop.find(f"{namespace}value")
            if kind is not None and value is not None:
                if kind.text == "SMILES":
                    drug_info["SMILES"] = value.text
                elif kind.text == "InChIKey":
                    drug_info["InChIKey"] = value.text

    # 'targets'セクションからターゲット情報を抽出
    targets = drug.find(f"{namespace}targets")
    if targets is not None:
        for target in targets:
            target_name = target.find(f"{namespace}name")
            if target_name is not None:
                drug_info["Targets Name"].append(target_name.text)

            polypeptide = target.find(f"{namespace}polypeptide")
            if polypeptide is not None and "id" in polypeptide.attrib:
                drug_info["Targets"].append(polypeptide.attrib["id"])

    drug_data_list.append(drug_info)

# Pandas DataFrameに変換
drug_df = pd.DataFrame(drug_data_list)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15235/15235 [00:00<00:00, 18353.06it/s]

# %%
drug_info
# Out:
# {'Drug Name': 'Xenon Xe-129',
#  'DrugBank ID': 'DB17386',
#  'PubChem CID': None,
#  'PubChem SID': None,
#  'SMILES': '[129Xe]',
#  'InChIKey': 'FHNFHKCVQCLJFQ-YPZZEJLDSA-N',
#  'Targets Name': [],
#  'Targets': []}

# %%
drug_df
# Out:
#                  Drug Name DrugBank ID PubChem CID PubChem SID  \
# 0                Lepirudin     DB00001        None    46507011
# 1                Cetuximab     DB00002        None    46507042
# 2             Dornase alfa     DB00003        None    46507792
# 3      Denileukin diftitox     DB00004        None    46506950
# 4               Etanercept     DB00005        None    46506732
# ...                    ...         ...         ...         ...
# 15230              AUM-601     DB17382        None        None
# 15231              FN-1501     DB17383        None        None
# 15232         Tinengotinib     DB17384        None        None
# 15233            Lipotecan     DB17385        None        None
# 15234         Xenon Xe-129     DB17386        None        None
#
#                                                   SMILES  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 15230                                               None
# 15231  CN1CCN(CC2=CC=C(NC(=O)C3=NNC=C3NC3=C4C=CNC4=NC...
# 15232  CC1=C2N=C(C3=CC=CC=C3Cl)C3=C(NC2=NN1)C=C(N=C3)...
# 15233  CC[C@@]1(OC(=O)C(C)ON=C2C3=C(C4=C2C=C(C=C4[N+]...
# 15234                                            [129Xe]
#
#                           InChIKey  \
# 0                             None
# 1                             None
# 2                             None
# 3                             None
# 4                             None
# ...                            ...
# 15230                         None
# 15231  VXLAKHWYGRKCGI-UHFFFAOYSA-N
# 15232  DQFCVOOFMXEPOC-UHFFFAOYSA-N
# 15233  JCCCLGDYMMTBPM-HXDHBHDHSA-N
# 15234  FHNFHKCVQCLJFQ-YPZZEJLDSA-N
#
#                                             Targets Name  \
# 0                                          [Prothrombin]
# 1      [Epidermal growth factor receptor, Low affinit...
# 2                                                  [DNA]
# 3      [Interleukin-2 receptor subunit alpha, Interle...
# 4      [Tumor necrosis factor, Lymphotoxin-alpha, Hig...
# ...                                                  ...
# 15230                                                 []
# 15231                                                 []
# 15232                                                 []
# 15233                                                 []
# 15234                                                 []
#
#                                                  Targets
# 0                                               [P00734]
# 1      [P00533, O75015, P02745, P02746, P02747, P0863...
# 2                                                     []
# 3                               [P01589, P14784, P31785]
# 4      [P01375, P01374, P12314, P12318, P31994, P3199...
# ...                                                  ...
# 15230                                                 []
# 15231                                                 []
# 15232                                                 []
# 15233                                                 []
# 15234                                                 []
#
# [15235 rows x 8 columns]

# %%
drug_df = drug_df[
    (drug_df["Targets"].astype(bool))
    #     & (~(drug_df['PubChem CID'].isna() & drug_df['PubChem SID'].isna() & drug_df['SMILES'].isna()))
].reset_index(drop=True)
drug_df
# Out:
#                      Drug Name DrugBank ID PubChem CID PubChem SID  \
# 0                    Lepirudin     DB00001        None    46507011
# 1                    Cetuximab     DB00002        None    46507042
# 2          Denileukin diftitox     DB00004        None    46506950
# 3                   Etanercept     DB00005        None    46506732
# 4                  Bivalirudin     DB00006    16129704    46507415
# ...                        ...         ...         ...         ...
# 7751  Betibeglogene autotemcel     DB16900        None        None
# 7752                   KW-6356     DB17080        None        None
# 7753                Linzagolix     DB17083        None        None
# 7754              JNJ-17216498     DB17087        None        None
# 7755                   UCB7362     DB17096        None        None
#
#                                                  SMILES  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4     CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@...
# ...                                                 ...
# 7751                                               None
# 7752                                               None
# 7753  COC1=C(COC2=C(OC)C=C(F)C(=C2)N2C(=O)NC3=CSC(C(...
# 7754                                               None
# 7755  C[C@H]1C[C@H](CCO1)N1C(=O)C[C@](C)(NC1=N)C1=C(...
#
#                                            Targets Name  \
# 0                                         [Prothrombin]
# 1     [Epidermal growth factor receptor, Low affinit...
# 2     [Interleukin-2 receptor subunit alpha, Interle...
# 3     [Tumor necrosis factor, Lymphotoxin-alpha, Hig...
# 4                                         [Prothrombin]
# ...                                                 ...
# 7751                                     [Alpha globin]
# 7752                           [Adenosine receptor A2a]
# 7753          [Gonadotropin-releasing hormone receptor]
# 7754                            [Histamine H3 receptor]
# 7755                       [Plasmepsin X, Plasmepsin X]
#
#                                                 Targets
# 0                                              [P00734]
# 1     [P00533, O75015, P02745, P02746, P02747, P0863...
# 2                              [P01589, P14784, P31785]
# 3     [P01375, P01374, P12314, P12318, P31994, P3199...
# 4                                              [P00734]
# ...                                                 ...
# 7751                                           [V9H1D9]
# 7752                                           [P29274]
# 7753                                           [P30968]
# 7754                                           [Q9Y5N1]
# 7755                                   [Q8IAS0, W7JWW5]
#
# [7756 rows x 7 columns]

# %%
drug_df = drug_df.drop(["PubChem CID", "PubChem SID"], axis=1)
drug_df.head()
# Out:
#              Drug Name DrugBank ID  \
# 0            Lepirudin     DB00001
# 1            Cetuximab     DB00002
# 2  Denileukin diftitox     DB00004
# 3           Etanercept     DB00005
# 4          Bivalirudin     DB00006
#
#                                               SMILES  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@...
#
#                                         Targets Name  \
# 0                                    ['Prothrombin']
# 1  ['Epidermal growth factor receptor', 'Low affi...
# 2  ['Interleukin-2 receptor subunit alpha', 'Inte...
# 3  ['Tumor necrosis factor', 'Lymphotoxin-alpha',...
# 4                                    ['Prothrombin']
#
#                                              Targets
# 0                                         ['P00734']
# 1  ['P00533', 'O75015', 'P02745', 'P02746', 'P027...
# 2                     ['P01589', 'P14784', 'P31785']
# 3  ['P01375', 'P01374', 'P12314', 'P12318', 'P319...
# 4                                         ['P00734']

# %%
db = pd.read_csv("/Users/yoshitakainoue/Downloads/drug links.csv")[
    [
        "DrugBank ID",
        "CAS Number",
        "KEGG Compound ID",
        "KEGG Drug ID",
        "PubChem Compound ID",
        "PubChem Substance ID",
        "ChEBI ID",
        "UniProt ID",
        "BindingDB ID",
    ]
]
db.head()
# Out:
#   DrugBank ID   CAS Number KEGG Compound ID KEGG Drug ID  PubChem Compound ID  \
# 0     DB00001  138068-37-8              NaN       D06880                  NaN
# 1     DB00002  205923-56-4              NaN       D03455                  NaN
# 2     DB00003  143831-71-4              NaN          NaN                  NaN
# 3     DB00004  173146-27-5              NaN          NaN                  NaN
# 4     DB00005  185243-69-0           C07897       D00742                  NaN
#
#    PubChem Substance ID  ChEBI ID UniProt ID  BindingDB ID
# 0            46507011.0       NaN     P01050           NaN
# 1            46507042.0       NaN        NaN           NaN
# 2            46507792.0       NaN     P24855           NaN
# 3            46506950.0       NaN     P00587           NaN
# 4            46506732.0       NaN     P20333           NaN

# %%
drug_df = drug_df.merge(db)
drug_df.head()
# Out:
#              Drug Name DrugBank ID  \
# 0            Lepirudin     DB00001
# 1            Cetuximab     DB00002
# 2  Denileukin diftitox     DB00004
# 3           Etanercept     DB00005
# 4          Bivalirudin     DB00006
#
#                                               SMILES  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@...
#
#                                         Targets Name  \
# 0                                    ['Prothrombin']
# 1  ['Epidermal growth factor receptor', 'Low affi...
# 2  ['Interleukin-2 receptor subunit alpha', 'Inte...
# 3  ['Tumor necrosis factor', 'Lymphotoxin-alpha',...
# 4                                    ['Prothrombin']
#
#                                              Targets   CAS Number  \
# 0                                         ['P00734']  138068-37-8
# 1  ['P00533', 'O75015', 'P02745', 'P02746', 'P027...  205923-56-4
# 2                     ['P01589', 'P14784', 'P31785']  173146-27-5
# 3  ['P01375', 'P01374', 'P12314', 'P12318', 'P319...  185243-69-0
# 4                                         ['P00734']  128270-60-0
#
#   KEGG Compound ID KEGG Drug ID  PubChem Compound ID  PubChem Substance ID  \
# 0              NaN       D06880                  NaN            46507011.0
# 1              NaN       D03455                  NaN            46507042.0
# 2              NaN          NaN                  NaN            46506950.0
# 3           C07897       D00742                  NaN            46506732.0
# 4              NaN       D03136           16129704.0            46507415.0
#
#    ChEBI ID UniProt ID  BindingDB ID
# 0       NaN     P01050           NaN
# 1       NaN        NaN           NaN
# 2       NaN     P00587           NaN
# 3       NaN     P20333           NaN
# 4   59173.0        NaN    50248103.0

# %%
drug_df["DrugBank ID"].to_csv("dbid.csv", index=False, header=None)

# %%
db_cid = pd.read_csv(
    "/Users/yoshitakainoue/Downloads/4512713032607354874.txt.gz", sep="\t", header=None
)
db_cid.dropna()
# Out:
#             0           1
# 4     DB00006  16129704.0
# 5     DB00007    657181.0
# 12    DB00014   5311128.0
# 30    DB00035   5311065.0
# 43    DB00050  25074887.0
# ...       ...         ...
# 7621  DB15588     64945.0
# 7623  DB15598    169535.0
# 7625  DB15617  86278348.0
# 7626  DB15623  53361968.0
# 7627  DB15624  11837140.0
#
# [6966 rows x 2 columns]

# %%
conv = dict(
    pd.DataFrame(
        np.concatenate(
            [
                db_cid.dropna().values,
                drug_df[["DrugBank ID", "PubChem Compound ID"]].dropna().values,
            ]
        )
    )
    .drop_duplicates()
    .values
)

# %%
drug_df["PubChem Compound ID"] = [
    conv[i] if i in conv.keys() else None for i in drug_df["DrugBank ID"]
]
drug_df
# Out:
#                      Drug Name DrugBank ID  \
# 0                    Lepirudin     DB00001
# 1                    Cetuximab     DB00002
# 2          Denileukin diftitox     DB00004
# 3                   Etanercept     DB00005
# 4                  Bivalirudin     DB00006
# ...                        ...         ...
# 7751  Betibeglogene autotemcel     DB16900
# 7752                   KW-6356     DB17080
# 7753                Linzagolix     DB17083
# 7754              JNJ-17216498     DB17087
# 7755                   UCB7362     DB17096
#
#                                                  SMILES  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@...
# ...                                                 ...
# 7751                                                NaN
# 7752                                                NaN
# 7753  COC1=C(COC2=C(OC)C=C(F)C(=C2)N2C(=O)NC3=CSC(C(...
# 7754                                                NaN
# 7755  C[C@H]1C[C@H](CCO1)N1C(=O)C[C@](C)(NC1=N)C1=C(...
#
#                                            Targets Name  \
# 0                                       ['Prothrombin']
# 1     ['Epidermal growth factor receptor', 'Low affi...
# 2     ['Interleukin-2 receptor subunit alpha', 'Inte...
# 3     ['Tumor necrosis factor', 'Lymphotoxin-alpha',...
# 4                                       ['Prothrombin']
# ...                                                 ...
# 7751                                   ['Alpha globin']
# 7752                         ['Adenosine receptor A2a']
# 7753        ['Gonadotropin-releasing hormone receptor']
# 7754                          ['Histamine H3 receptor']
# 7755                   ['Plasmepsin X', 'Plasmepsin X']
#
#                                                 Targets    CAS Number  \
# 0                                            ['P00734']   138068-37-8
# 1     ['P00533', 'O75015', 'P02745', 'P02746', 'P027...   205923-56-4
# 2                        ['P01589', 'P14784', 'P31785']   173146-27-5
# 3     ['P01375', 'P01374', 'P12314', 'P12318', 'P319...   185243-69-0
# 4                                            ['P00734']   128270-60-0
# ...                                                 ...           ...
# 7751                                         ['V9H1D9']           NaN
# 7752                                         ['P29274']           NaN
# 7753                                         ['P30968']   935283-04-8
# 7754                                         ['Q9Y5N1']  1035626-05-1
# 7755                               ['Q8IAS0', 'W7JWW5']           NaN
#
#      KEGG Compound ID KEGG Drug ID  PubChem Compound ID  PubChem Substance ID  \
# 0                 NaN       D06880                  NaN            46507011.0
# 1                 NaN       D03455                  NaN            46507042.0
# 2                 NaN          NaN                  NaN            46506950.0
# 3              C07897       D00742                  NaN            46506732.0
# 4                 NaN       D03136           16129704.0            46507415.0
# ...               ...          ...                  ...                   ...
# 7751              NaN          NaN                  NaN                   NaN
# 7752              NaN          NaN                  NaN                   NaN
# 7753              NaN          NaN                  NaN                   NaN
# 7754              NaN          NaN                  NaN                   NaN
# 7755              NaN          NaN                  NaN                   NaN
#
#       ChEBI ID UniProt ID  BindingDB ID
# 0          NaN     P01050           NaN
# 1          NaN        NaN           NaN
# 2          NaN     P00587           NaN
# 3          NaN     P20333           NaN
# 4      59173.0        NaN    50248103.0
# ...        ...        ...           ...
# 7751       NaN        NaN           NaN
# 7752       NaN        NaN           NaN
# 7753       NaN        NaN      160329.0
# 7754       NaN        NaN           NaN
# 7755       NaN        NaN           NaN
#
# [7756 rows x 13 columns]

# %%
db_smiles = pd.read_csv(
    "/Users/yoshitakainoue/Downloads/119911432016837011.txt.gz", sep="\t", header=None
).dropna()
db_smiles
# Out:
#             0                                                  1
# 4     DB00006  CC[C@H](C)[C@@H](C(=O)N1CCC[C@H]1C(=O)N[C@@H](...
# 5     DB00007  CCNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCN=C(N)N)NC(=...
# 12    DB00014  CC(C)C[C@@H](C(=O)N[C@@H](CCCN=C(N)N)C(=O)N1CC...
# 30    DB00035  C1C[C@H](N(C1)C(=O)[C@@H]2CSSCCC(=O)N[C@H](C(=...
# 43    DB00050  C[C@H](C(=O)N)NC(=O)[C@@H]1CCCN1C(=O)[C@H](CCC...
# ...       ...                                                ...
# 7621  DB15588  C[C@@H]1CC[C@@]2(CC[C@@]3(C(=CC[C@H]4[C@]3(CC[...
# 7623  DB15598  CC1=C(C(=O)C=CO1)[O-].CC1=C(C(=O)C=CO1)[O-].CC...
# 7625  DB15617  C([C@@H]1[C@H]([C@@H]([C@H]([C@H](O1)OC[C@@H]2...
# 7626  DB15623  CC(C)CN(C[C@H]([C@H](CC1=CC=CC=C1)NC(=O)O[C@H]...
# 7627  DB15624             C1=C(SC(=N1)SC2=NN=C(S2)N)[N+](=O)[O-]
#
# [6966 rows x 2 columns]

# %%
conv = dict(
    pd.DataFrame(
        np.concatenate(
            [
                db_smiles.dropna().values,
                drug_df[["DrugBank ID", "SMILES"]].dropna().values,
            ]
        )
    )
    .drop_duplicates()
    .values
)

# %%
len(conv.keys())
# Out:
# 7055

# %%
drug_df["SMILES"] = [
    conv[i] if i in conv.keys() else None for i in drug_df["DrugBank ID"]
]
drug_df.head()
# Out:
#              Drug Name DrugBank ID  \
# 0            Lepirudin     DB00001
# 1            Cetuximab     DB00002
# 2  Denileukin diftitox     DB00004
# 3           Etanercept     DB00005
# 4          Bivalirudin     DB00006
#
#                                               SMILES  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@...
#
#                                         Targets Name  \
# 0                                    ['Prothrombin']
# 1  ['Epidermal growth factor receptor', 'Low affi...
# 2  ['Interleukin-2 receptor subunit alpha', 'Inte...
# 3  ['Tumor necrosis factor', 'Lymphotoxin-alpha',...
# 4                                    ['Prothrombin']
#
#                                              Targets   CAS Number  \
# 0                                         ['P00734']  138068-37-8
# 1  ['P00533', 'O75015', 'P02745', 'P02746', 'P027...  205923-56-4
# 2                     ['P01589', 'P14784', 'P31785']  173146-27-5
# 3  ['P01375', 'P01374', 'P12314', 'P12318', 'P319...  185243-69-0
# 4                                         ['P00734']  128270-60-0
#
#   KEGG Compound ID KEGG Drug ID  PubChem Compound ID  PubChem Substance ID  \
# 0              NaN       D06880                  NaN            46507011.0
# 1              NaN       D03455                  NaN            46507042.0
# 2              NaN          NaN                  NaN            46506950.0
# 3           C07897       D00742                  NaN            46506732.0
# 4              NaN       D03136           16129704.0            46507415.0
#
#    ChEBI ID UniProt ID  BindingDB ID
# 0       NaN     P01050           NaN
# 1       NaN        NaN           NaN
# 2       NaN     P00587           NaN
# 3       NaN     P20333           NaN
# 4   59173.0        NaN    50248103.0

# %%
drug_df[
    [
        "Drug Name",
        "DrugBank ID",
        "Targets Name",
        "Targets",
        "SMILES",
        "PubChem Compound ID",
        "PubChem Substance ID",
    ]
].to_csv("drug_bank.csv")
