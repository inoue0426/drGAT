# %%
import optuna

# %%
name = "GDSC2_GAT"
study = optuna.create_study(
    storage="sqlite:///{}.sqlite3".format(name),
    study_name=name,
    load_if_exists=True,
)
df = study.trials_dataframe().dropna(
    subset=["values_0", "values_1", "values_2", "values_3"]
)
df = df[
    ~(
        (df["values_0"] == float("-inf"))
        | (df["values_1"] == float("-inf"))
        | (df["values_2"] == float("-inf"))
        | (df["values_3"] == float("-inf"))
    )
]
df
# Out:
# [I 2025-03-22 11:43:24,465] Using an existing study with name 'GDSC2_GAT' instead of creating a new one.
#     number  values_0  values_1  values_2  values_3             datetime_start  \
# 11      11  0.780596  0.897198  0.904858  0.741584 2025-03-21 18:30:52.844003
#
#             datetime_complete               duration  params_T_max  \
# 11 2025-03-21 18:31:13.200357 0 days 00:00:20.356354           NaN
#
#    params_activation  ... params_nesterov  params_optimizer  \
# 11             swish  ...            True               SGD
#
#     params_patience_plateau  params_scheduler  params_step_size  \
# 11                      3.0           Plateau               NaN
#
#     params_thresh_plateau params_weight_decay  \
# 11               0.002575            0.000005
#
#     user_attrs_early_stopping_epoch  user_attrs_status     state
# 11                              NaN                NaN  COMPLETE
#
# [1 rows x 33 columns]

# %%
name = "GDSC2"
study = optuna.create_study(
    storage="sqlite:///{}_{}.sqlite3".format(name, "GCN_MPNN"),
    study_name=name,
    load_if_exists=True,
)
df = study.trials_dataframe().dropna(
    subset=["values_0", "values_1", "values_2", "values_3"]
)
df = df[
    ~(
        (df["values_0"] == float("-inf"))
        | (df["values_1"] == float("-inf"))
        | (df["values_2"] == float("-inf"))
        | (df["values_3"] == float("-inf"))
    )
]
df
# Out:
# [I 2025-03-22 11:43:27,976] Using an existing study with name 'GDSC2' instead of creating a new one.
#      number  values_0  values_1  values_2  values_3  \
# 0         0  0.737520  0.917582  0.915013  0.658281
# 1         1  0.683977  0.916411  0.917369  0.551685
# 3         3  0.716989  0.912845  0.917864  0.624265
# 4         4  0.721014  0.917896  0.915877  0.626817
# 7         7  0.710950  0.920788  0.920546  0.607650
# ..      ...       ...       ...       ...       ...
# 189     189  0.683977  0.913720  0.922984  0.552707
# 190     190  0.667874  0.912627  0.920650  0.518950
# 191     191  0.667874  0.916487  0.924412  0.518950
# 192     192  0.741948  0.925182  0.923742  0.665274
# 193     193  0.684783  0.917254  0.922023  0.554354
#
#                 datetime_start          datetime_complete  \
# 0   2025-03-21 18:30:47.028472 2025-03-21 18:32:03.952397
# 1   2025-03-21 18:30:47.039103 2025-03-21 18:32:11.482431
# 3   2025-03-21 18:30:47.060929 2025-03-21 18:31:42.949192
# 4   2025-03-21 18:30:47.074361 2025-03-21 18:32:11.765006
# 7   2025-03-21 18:30:47.131602 2025-03-21 18:31:52.860565
# ..                         ...                        ...
# 189 2025-03-21 18:48:34.888682 2025-03-21 18:53:39.625030
# 190 2025-03-21 18:48:51.377303 2025-03-21 18:53:57.070034
# 191 2025-03-21 18:48:52.103111 2025-03-21 18:53:53.012979
# 192 2025-03-21 18:49:01.229578 2025-03-21 18:54:01.087633
# 193 2025-03-21 18:49:04.814674 2025-03-21 18:53:59.395018
#
#                   duration  params_T_max params_activation  ...  \
# 0   0 days 00:01:16.923925           NaN             swish  ...
# 1   0 days 00:01:24.443328           NaN             swish  ...
# 3   0 days 00:00:55.888263           NaN              gelu  ...
# 4   0 days 00:01:24.690645          35.0              relu  ...
# 7   0 days 00:01:05.728963           NaN             swish  ...
# ..                     ...           ...               ...  ...
# 189 0 days 00:05:04.736348           NaN             swish  ...
# 190 0 days 00:05:05.692731           NaN             swish  ...
# 191 0 days 00:05:00.909868           NaN             swish  ...
# 192 0 days 00:04:59.858055           NaN             swish  ...
# 193 0 days 00:04:54.580344           NaN             swish  ...
#
#     params_nesterov  params_optimizer  params_patience_plateau  \
# 0               NaN             AdamW                      NaN
# 1               NaN             AdamW                      9.0
# 3               NaN             AdamW                      8.0
# 4               NaN              Adam                      NaN
# 7               NaN             AdamW                      NaN
# ..              ...               ...                      ...
# 189           False               SGD                      7.0
# 190           False               SGD                      7.0
# 191           False               SGD                      7.0
# 192           False               SGD                      NaN
# 193           False               SGD                      NaN
#
#      params_scheduler  params_step_size  params_thresh_plateau  \
# 0                Step              30.0                    NaN
# 1             Plateau               NaN               0.000122
# 3             Plateau               NaN               0.001495
# 4              Cosine               NaN                    NaN
# 7                None               NaN                    NaN
# ..                ...               ...                    ...
# 189           Plateau               NaN               0.004391
# 190           Plateau               NaN               0.004015
# 191           Plateau               NaN               0.004324
# 192              None               NaN                    NaN
# 193              None               NaN                    NaN
#
#     params_weight_decay  user_attrs_early_stopping_epoch  user_attrs_status  \
# 0              0.000002                              NaN                NaN
# 1              0.005874                              NaN                NaN
# 3              0.000299                              NaN                NaN
# 4              0.000002                              NaN                NaN
# 7              0.000003                              NaN                NaN
# ..                  ...                              ...                ...
# 189            0.000775                              NaN                NaN
# 190            0.000135                              NaN                NaN
# 191            0.000041                              NaN                NaN
# 192            0.000475                              NaN                NaN
# 193            0.001265                              NaN                NaN
#
#         state
# 0    COMPLETE
# 1    COMPLETE
# 3    COMPLETE
# 4    COMPLETE
# 7    COMPLETE
# ..        ...
# 189  COMPLETE
# 190  COMPLETE
# 191  COMPLETE
# 192  COMPLETE
# 193  COMPLETE
#
# [149 rows x 32 columns]
