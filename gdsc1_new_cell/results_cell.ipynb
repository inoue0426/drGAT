# %%
import os
import sys

import optuna
import pandas as pd

current_dir = os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, ".."))
sys.path.append(parent_dir)

from metrics import get_parsed_df

# %%
task = 'cell'
method = "GATv2"
study = optuna.create_study(
    storage=f"sqlite:///{method}_{task}_small.sqlite3",
    study_name=method,
    load_if_exists=True,
)
tmp = study.trials_dataframe().dropna(
    subset=["values_0", "values_1", "values_2", "values_3"]
)
tmp = tmp[[i for i in tmp.columns if "params" in i]]
df = (
    study.trials_dataframe()
    .dropna(subset=["values_0", "values_1", "values_2", "values_3"])
    .iloc[:, 20:-2]
)
df.columns = [i.replace("user_attrs_", "") for i in df.columns]

print(df.shape)
n = df.shape[0]
if n > 0:
    parsed_df = get_parsed_df(df)
    parsed_df = pd.concat([parsed_df, tmp], axis=1)
    parsed_df.sort_values("AUPR", ascending=False).head()

parsed_df if n > 0 else None
# Out:
# [I 2025-04-12 17:31:50,573] Using an existing study with name 'GATv2' instead of creating a new one.
# (0, 0)

# %%
parsed_df.sort_values('ACC', ascending=False).head(3)
# Out:
# KeyboardInterrupt

# %%
parsed_df.sort_values('AUPR', ascending=False).head(3)

# %%
parsed_df.sort_values('AUROC', ascending=False).head(3)

# %%
method = "Transformer"
study = optuna.create_study(
    storage=f"sqlite:///{method}_{task}_small.sqlite3",
    study_name=method,
    load_if_exists=True,
)
tmp = study.trials_dataframe().dropna(
    subset=["values_0", "values_1", "values_2", "values_3"]
)
tmp = tmp[[i for i in tmp.columns if "params" in i]]
df = (
    study.trials_dataframe()
    .dropna(subset=["values_0", "values_1", "values_2", "values_3"])
    .iloc[:, 20:-2]
)
df.columns = [i.replace("user_attrs_", "") for i in df.columns]

print(df.shape)
n = df.shape[0]
if n > 0:
    parsed_df = get_parsed_df(df)
    parsed_df = pd.concat([parsed_df, tmp], axis=1)
    parsed_df.sort_values("AUPR", ascending=False).head()
# Out:
# [I 2025-04-12 17:31:52,766] Using an existing study with name 'Transformer' instead of creating a new one.
# (0, 0)

# %%
parsed_df.sort_values('ACC', ascending=False).head(3)

# %%
parsed_df.sort_values('AUPR', ascending=False).head(3)

# %%
parsed_df.sort_values('AUROC', ascending=False).head(3)

# %%
method = "GAT"
study = optuna.create_study(
    storage=f"sqlite:///{method}_{task}_small.sqlite3",
    study_name=method,
    load_if_exists=True,
)
tmp = study.trials_dataframe().dropna(
    subset=["values_0", "values_1", "values_2", "values_3"]
)
tmp = tmp[[i for i in tmp.columns if "params" in i]]
df = (
    study.trials_dataframe()
    .dropna(subset=["values_0", "values_1", "values_2", "values_3"])
    .iloc[:, 20:-2]
)
df.columns = [i.replace("user_attrs_", "") for i in df.columns]

print(df.shape)
n = df.shape[0]
if n > 0:
    parsed_df = get_parsed_df(df)
    parsed_df = pd.concat([parsed_df, tmp], axis=1)
    parsed_df.sort_values("AUPR", ascending=False).head()

parsed_df.head() if n > 0 else None
# Out:
# [I 2025-04-12 17:31:54,060] Using an existing study with name 'GAT' instead of creating a new one.
# (0, 0)

# %%
parsed_df.sort_values('ACC', ascending=False).head(3)
# Out:
#                   ACC               AUPR              AUROC  \
# 43  0.5012 (± 0.0128)  0.5195 (± 0.0429)  0.5002 (± 0.0512)
# 34  0.5007 (± 0.0145)  0.5199 (± 0.0412)     0.501 (± 0.05)
# 30  0.5006 (± 0.0155)  0.5203 (± 0.0443)  0.5005 (± 0.0538)
#
#          Balanced_ACC                 F1             Recall  \
# 43  0.5012 (± 0.0128)   0.1776 (± 0.278)  0.2426 (± 0.4055)
# 34  0.5007 (± 0.0145)  0.2607 (± 0.3094)  0.3661 (± 0.4595)
# 30  0.5006 (± 0.0155)   0.2988 (± 0.311)  0.4153 (± 0.4631)
#
#             Precision  params_T_max params_activation  params_dropout1  \
# 43  0.2075 (± 0.2908)           NaN              gelu             0.50
# 34  0.2755 (± 0.2945)           1.0              relu             0.15
# 30  0.3164 (± 0.2951)           1.0              gelu             0.10
#
#     params_dropout2  params_heads  params_hidden1  params_hidden2  \
# 43              0.5             2             413             363
# 34              0.2             2             456             278
# 30              0.3             2             977             107
#
#     params_hidden3  params_lr params_optimizer params_scheduler  \
# 43              98   0.000209            AdamW             None
# 34             124   0.000033            AdamW           Cosine
# 30             107   0.000013            AdamW           Cosine
#
#     params_weight_decay
# 43             0.000804
# 34             0.000086
# 30             0.000868

# %%
parsed_df.sort_values('AUPR', ascending=False).head(3)
# Out:
#                   ACC               AUPR              AUROC  \
# 1      0.5 (± 0.0068)  0.5259 (± 0.0528)   0.505 (± 0.0609)
# 40  0.4997 (± 0.0084)   0.5232 (± 0.046)  0.5048 (± 0.0563)
# 6    0.5006 (± 0.009)   0.5231 (± 0.043)  0.5052 (± 0.0525)
#
#          Balanced_ACC                 F1             Recall  \
# 1      0.5 (± 0.0068)   0.102 (± 0.2351)  0.1471 (± 0.3466)
# 40  0.4997 (± 0.0084)  0.1884 (± 0.2951)   0.2747 (± 0.438)
# 6    0.5006 (± 0.009)  0.1701 (± 0.2795)  0.2401 (± 0.4125)
#
#             Precision  params_T_max params_activation  params_dropout1  \
# 1   0.0882 (± 0.1962)           1.0              gelu              0.5
# 40  0.1555 (± 0.2376)           2.0              relu              0.4
# 6     0.185 (± 0.278)           2.0              relu              0.5
#
#     params_dropout2  params_heads  params_hidden1  params_hidden2  \
# 1              0.20             4             663             220
# 40             0.25             2             374             288
# 6              0.15             3             272             265
#
#     params_hidden3  params_lr params_optimizer params_scheduler  \
# 1              170   0.008701            AdamW           Cosine
# 40             210   0.003411            AdamW           Cosine
# 6              128   0.000173             Adam           Cosine
#
#     params_weight_decay
# 1              0.003702
# 40             0.004558
# 6              0.000001

# %%
parsed_df.sort_values('AUROC', ascending=False).head(3)
# Out:
#                   ACC               AUPR              AUROC  \
# 6    0.5006 (± 0.009)   0.5231 (± 0.043)  0.5052 (± 0.0525)
# 1      0.5 (± 0.0068)  0.5259 (± 0.0528)   0.505 (± 0.0609)
# 40  0.4997 (± 0.0084)   0.5232 (± 0.046)  0.5048 (± 0.0563)
#
#          Balanced_ACC                 F1             Recall  \
# 6    0.5006 (± 0.009)  0.1701 (± 0.2795)  0.2401 (± 0.4125)
# 1      0.5 (± 0.0068)   0.102 (± 0.2351)  0.1471 (± 0.3466)
# 40  0.4997 (± 0.0084)  0.1884 (± 0.2951)   0.2747 (± 0.438)
#
#             Precision  params_T_max params_activation  params_dropout1  \
# 6     0.185 (± 0.278)           2.0              relu              0.5
# 1   0.0882 (± 0.1962)           1.0              gelu              0.5
# 40  0.1555 (± 0.2376)           2.0              relu              0.4
#
#     params_dropout2  params_heads  params_hidden1  params_hidden2  \
# 6              0.15             3             272             265
# 1              0.20             4             663             220
# 40             0.25             2             374             288
#
#     params_hidden3  params_lr params_optimizer params_scheduler  \
# 6              128   0.000173             Adam           Cosine
# 1              170   0.008701            AdamW           Cosine
# 40             210   0.003411            AdamW           Cosine
#
#     params_weight_decay
# 6              0.000001
# 1              0.003702
# 40             0.004558

# %%
method = "MPNN"
study = optuna.create_study(
    storage=f"sqlite:///{method}_{task}_small.sqlite3",
    study_name=method,
    load_if_exists=True,
)
tmp = study.trials_dataframe().dropna(
    subset=["values_0", "values_1", "values_2", "values_3"]
)
tmp = tmp[[i for i in tmp.columns if "params" in i]]
df = (
    study.trials_dataframe()
    .dropna(subset=["values_0", "values_1", "values_2", "values_3"])
    .iloc[:, 19:-2]
)
df.columns = [i.replace("user_attrs_", "") for i in df.columns]

print(df.shape)
n = df.shape[0]
if n > 0:
    parsed_df = get_parsed_df(df)
    parsed_df = pd.concat([parsed_df, tmp], axis=1)
    parsed_df.sort_values("AUPR", ascending=False).head()

parsed_df if n > 0 else None
# Out:
# [I 2025-04-12 17:31:56,121] Using an existing study with name 'MPNN' instead of creating a new one.
# (1, 23)
#                 ACC               AUPR              AUROC      Balanced_ACC  \
# 1  0.508 (± 0.0048)  0.5652 (± 0.0437)  0.5609 (± 0.0489)  0.508 (± 0.0048)
#
#                   F1             Recall          Precision  params_T_max  \
# 1  0.0316 (± 0.0173)  0.0161 (± 0.0089)  0.8542 (± 0.3531)           NaN
#
#   params_activation  params_dropout1  params_dropout2  params_heads  \
# 1              relu              0.2             0.45             3
#
#    params_hidden1  params_hidden2  params_hidden3  params_lr params_optimizer  \
# 1             901             394             150   0.000056             Adam
#
#   params_scheduler  params_weight_decay
# 1             None             0.001666

# %%
parsed_df.sort_values('ACC', ascending=False).head(3)

# %%
parsed_df.sort_values('AUPR', ascending=False).head(3)

# %%
parsed_df.sort_values('AUROC', ascending=False).head(3)

# %%
for i in parsed_df['ACC']:
    if '0.5' in i:
        print(i)

# %%
method = "GCN"
study = optuna.create_study(
    storage=f"sqlite:///{method}_{task}_small.sqlite3",
    study_name=method,
    load_if_exists=True,
)
tmp = study.trials_dataframe().dropna(
    subset=["values_0", "values_1", "values_2", "values_3"]
)
tmp = tmp[[i for i in tmp.columns if "params" in i]]
df = (
    study.trials_dataframe()
    .dropna(subset=["values_0", "values_1", "values_2", "values_3"])
    .iloc[:, 20:-2]
)
df.columns = [i.replace("user_attrs_", "") for i in df.columns]

print(df.shape)
n = df.shape[0]
if n > 0:
    parsed_df = get_parsed_df(df)
    parsed_df = pd.concat([parsed_df, tmp], axis=1)
    parsed_df.sort_values("AUPR", ascending=False).head()

parsed_df if n > 0 else None
# Out:
# [I 2025-04-12 17:31:57,717] Using an existing study with name 'GCN' instead of creating a new one.
# (5, 22)
#                  ACC               AUPR              AUROC       Balanced_ACC  \
# 0   0.5034 (± 0.005)   0.5445 (± 0.045)  0.5229 (± 0.0554)   0.5034 (± 0.005)
# 1   0.5036 (± 0.005)  0.5603 (± 0.0449)  0.5472 (± 0.0523)   0.5036 (± 0.005)
# 2  0.5044 (± 0.0054)  0.5426 (± 0.0463)  0.5218 (± 0.0569)  0.5044 (± 0.0054)
# 3  0.5083 (± 0.0047)  0.5756 (± 0.0446)  0.5666 (± 0.0481)  0.5083 (± 0.0047)
# 4   0.5034 (± 0.005)  0.5306 (± 0.0438)  0.5088 (± 0.0566)   0.5034 (± 0.005)
#
#                   F1             Recall          Precision  params_T_max  \
# 0  0.0134 (± 0.0195)    0.0069 (± 0.01)  0.3629 (± 0.4811)           NaN
# 1  0.0142 (± 0.0193)  0.0073 (± 0.0099)  0.3904 (± 0.4881)          44.0
# 2  0.0173 (± 0.0207)  0.0088 (± 0.0106)  0.4616 (± 0.4988)           NaN
# 3  0.0326 (± 0.0169)  0.0167 (± 0.0087)  0.8783 (± 0.3271)           NaN
# 4  0.0135 (± 0.0193)  0.0069 (± 0.0099)  0.3695 (± 0.4829)           NaN
#
#   params_activation  params_dropout1  params_dropout2  params_heads  \
# 0              relu             0.50             0.25             7
# 1              gelu             0.35             0.45             2
# 2              relu             0.20             0.20             2
# 3              relu             0.45             0.30             2
# 4              relu             0.10             0.40             6
#
#    params_hidden1  params_hidden2  params_hidden3  params_lr params_optimizer  \
# 0             859             100             100   0.000013            AdamW
# 1             981             444             234   0.000093             Adam
# 2             535             174              53   0.000023             Adam
# 3             635             391             228   0.000116            AdamW
# 4             703             122              48   0.000011            AdamW
#
#   params_scheduler  params_weight_decay
# 0             None             0.000519
# 1           Cosine             0.000010
# 2             None             0.000007
# 3             None             0.000021
# 4             None             0.000022

# %%
for i in parsed_df['ACC']:
    if '0.5' in i:
        print(i)

# %%
parsed_df.sort_values('ACC', ascending=False).head(3)

# %%
parsed_df.sort_values('AUPR', ascending=False).head(3)

# %%
parsed_df.sort_values('AUROC', ascending=False).head(3)
